# %%
import numpy as np
import uproot as uproot
import uproot3 as uproot3
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd

from tqdm.notebook import tqdm

import pickle

# %%
# three_bin refers to the fact that I'm constraining M_A, NormCCMEC, and Lambda all at the same time

# this file uses the saved pickle outputs from MA_trio.ipynb

# %%
nuwro_fake_data_true_MA = 1.03 # From Afro slack 2024_06_10
genie_v2_fake_data_true_MA = 0.99 # Nitish slack 2023_04_25

# %%
with open('trio_pickles/nuwro_fake_rate+shape_3d.pkl', 'rb') as handle:
    tup = pickle.load(handle)

    prior_trio, prior_cov = tup[0], tup[1]
    nuwro_constrained_trio, nuwro_constrained_trio_cov = tup[2], tup[3]
    nuwro_asimov_constrained_trio, nuwro_asimov_constrained_trio_cov = tup[4], tup[5]
    nuwro_cov_mat_true_trios, nuwro_cov_mat_trios, nuwro_cov_mat_trio_covs = tup[6], tup[7], tup[8]
    nuwro_xs_cov_mat_true_trios, nuwro_xs_cov_mat_trios, nuwro_xs_cov_mat_trio_covs = tup[9], tup[10], tup[11]
    nuwro_genie_true_trios, nuwro_genie_trios, nuwro_genie_trio_covs = tup[12], tup[13], tup[14]

prior_MA = prior_trio[0]
prior_MA_sigma = np.sqrt(prior_cov[0,0])
asimov_true_MA = prior_trio[0]

p = prior_MA
dp = prior_MA_sigma

nuwro_reco_MA = nuwro_constrained_trio[0]
nuwro_reco_MA_sigma = np.sqrt(nuwro_constrained_trio_cov[0,0])
x = nuwro_reco_MA
dx = nuwro_reco_MA_sigma
nuwro_reco_MA_prior_removed = (dp * dp * x - dx * dx * p) / (dp * dp - dx * dx)
nuwro_reco_MA_sigma_prior_removed = (dp * dx) / np.sqrt(dp * dp - dx * dx)

asimov_true_MA = prior_trio[0]
asimov_reco_MA = nuwro_asimov_constrained_trio[0]
asimov_reco_MA_sigma = np.sqrt(nuwro_asimov_constrained_trio_cov[0,0])
x = asimov_reco_MA
dx = asimov_reco_MA_sigma
asimov_reco_MA_prior_removed = (dp * dp * x - dx * dx * p) / (dp * dp - dx * dx)
asimov_reco_MA_sigma_prior_removed = (dp * dx) / np.sqrt(dp * dp - dx * dx)

nuwro_cov_mat_true_MAs = np.array([x[0] for x in nuwro_cov_mat_true_trios])
nuwro_cov_mat_reco_MAs = np.array([x[0] for x in nuwro_cov_mat_trios])
nuwro_cov_mat_reco_MA_sigmas = [np.sqrt(x[0,0]) for x in nuwro_cov_mat_trio_covs]
x = nuwro_cov_mat_reco_MAs
dx = nuwro_cov_mat_reco_MA_sigmas
nuwro_cov_mat_reco_MAs_prior_removed = [(dp * dp * x[i] - dx[i] * dx[i] * p) / (dp * dp - dx[i] * dx[i]) for i in range(len(x))]
nuwro_cov_mat_reco_MA_sigmas_prior_removed = [(dp * dx[i]) / np.sqrt(dp * dp - dx[i] * dx[i]) for i in range(len(x))]

nuwro_xs_cov_mat_true_MAs = np.array([x[0] for x in nuwro_xs_cov_mat_true_trios])
nuwro_xs_cov_mat_reco_MAs = np.array([x[0] for x in nuwro_xs_cov_mat_trios])
nuwro_xs_cov_mat_reco_MA_sigmas = np.array([np.sqrt(x[0,0]) for x in nuwro_xs_cov_mat_trio_covs])
x = nuwro_xs_cov_mat_reco_MAs
dx = nuwro_xs_cov_mat_reco_MA_sigmas
nuwro_xs_cov_mat_reco_MAs_prior_removed = np.array([(dp * dp * x[i] - dx[i] * dx[i] * p) / (dp * dp - dx[i] * dx[i]) for i in range(len(x))])
nuwro_xs_cov_mat_reco_MA_sigmas_prior_removed = np.array([(dp * dx[i]) / np.sqrt(dp * dp - dx[i] * dx[i]) for i in range(len(x))])

nuwro_genie_true_MAs = np.array([x[0] for x in nuwro_genie_true_trios])
nuwro_genie_reco_MAs = np.array([x[0] for x in nuwro_genie_trios])
nuwro_genie_reco_MA_sigmas = np.array([np.sqrt(x[0,0]) for x in nuwro_genie_trio_covs])
x = nuwro_genie_reco_MAs
dx = nuwro_genie_reco_MA_sigmas
nuwro_genie_reco_MAs_prior_removed = np.array([(dp * dp * x[i] - dx[i] * dx[i] * p) / (dp * dp - dx[i] * dx[i]) for i in range(len(x))])
nuwro_genie_reco_MA_sigmas_prior_removed = np.array([(dp * dx[i]) / np.sqrt(dp * dp - dx[i] * dx[i]) for i in range(len(x))])

# %%
with open('trio_pickles/nuwro_fake_+100_3d.pkl', 'rb') as handle:
    tup = pickle.load(handle)

    prior_trio_plus100, prior_cov_plus100 = tup[0], tup[1]
    nuwro_constrained_trio_plus100, nuwro_constrained_trio_cov_plus100 = tup[2], tup[3]
    nuwro_asimov_constrained_trio_plus100, nuwro_asimov_constrained_trio_cov_plus100 = tup[4], tup[5]
    nuwro_cov_mat_true_trios_plus100, nuwro_cov_mat_trios_plus100, nuwro_cov_mat_trio_covs_plus100 = tup[6], tup[7], tup[8]
    nuwro_xs_cov_mat_true_trios_plus100, nuwro_xs_cov_mat_trios_plus100, nuwro_xs_cov_mat_trio_covs_plus100 = tup[9], tup[10], tup[11]
    nuwro_genie_true_trios_plus100, nuwro_genie_trios_plus100, nuwro_genie_trio_covs_plus100 = tup[12], tup[13], tup[14]

nuwro_reco_MA_plus100 = nuwro_constrained_trio_plus100[0]
nuwro_reco_MA_sigma_plus100 = np.sqrt(nuwro_constrained_trio_cov_plus100[0,0])
x = nuwro_reco_MA_plus100
dx = nuwro_reco_MA_sigma_plus100
nuwro_reco_MA_prior_removed_plus100 = (dp * dp * x - dx * dx * p) / (dp * dp - dx * dx)
nuwro_reco_MA_sigma_prior_removed_plus100 = (dp * dx) / np.sqrt(dp * dp - dx * dx)

asimov_true_MA_plus100 = prior_trio_plus100[0]
asimov_reco_MA_plus100 = nuwro_asimov_constrained_trio_plus100[0]
asimov_reco_MA_sigma_plus100 = np.sqrt(nuwro_asimov_constrained_trio_cov_plus100[0,0])
x = asimov_reco_MA_plus100
dx = asimov_reco_MA_sigma_plus100
asimov_reco_MA_prior_removed_plus100 = (dp * dp * x - dx * dx * p) / (dp * dp - dx * dx)
asimov_reco_MA_sigma_prior_removed_plus100 = (dp * dx) / np.sqrt(dp * dp - dx * dx)

nuwro_cov_mat_true_MAs_plus100 = np.array([x[0] for x in nuwro_cov_mat_true_trios_plus100])
nuwro_cov_mat_reco_MAs_plus100 = np.array([x[0] for x in nuwro_cov_mat_trios_plus100])
nuwro_cov_mat_reco_MA_sigmas_plus100 = [np.sqrt(x[0,0]) for x in nuwro_cov_mat_trio_covs_plus100]
x = nuwro_cov_mat_reco_MAs_plus100
dx = nuwro_cov_mat_reco_MA_sigmas_plus100
nuwro_cov_mat_reco_MAs_prior_removed_plus100 = [(dp * dp * x[i] - dx[i] * dx[i] * p) / (dp * dp - dx[i] * dx[i]) for i in range(len(x))]
nuwro_cov_mat_reco_MA_sigmas_prior_removed_plus100 = [(dp * dx[i]) / np.sqrt(dp * dp - dx[i] * dx[i]) for i in range(len(x))]

nuwro_xs_cov_mat_true_MAs_plus100 = np.array([x[0] for x in nuwro_xs_cov_mat_true_trios_plus100])
nuwro_xs_cov_mat_reco_MAs_plus100 = np.array([x[0] for x in nuwro_xs_cov_mat_trios_plus100])
nuwro_xs_cov_mat_reco_MA_sigmas_plus100 = np.array([np.sqrt(x[0,0]) for x in nuwro_xs_cov_mat_trio_covs_plus100])
x = nuwro_xs_cov_mat_reco_MAs_plus100
dx = nuwro_xs_cov_mat_reco_MA_sigmas_plus100
nuwro_xs_cov_mat_reco_MAs_prior_removed_plus100 = np.array([(dp * dp * x[i] - dx[i] * dx[i] * p) / (dp * dp - dx[i] * dx[i]) for i in range(len(x))])
nuwro_xs_cov_mat_reco_MA_sigmas_prior_removed_plus100 = np.array([(dp * dx[i]) / np.sqrt(dp * dp - dx[i] * dx[i]) for i in range(len(x))])

nuwro_genie_true_MAs_plus100 = np.array([x[0] for x in nuwro_genie_true_trios_plus100])
nuwro_genie_reco_MAs_plus100 = np.array([x[0] for x in nuwro_genie_trios_plus100])
nuwro_genie_reco_MA_sigmas_plus100 = np.array([np.sqrt(x[0,0]) for x in nuwro_genie_trio_covs_plus100])
x = nuwro_genie_reco_MAs_plus100
dx = nuwro_genie_reco_MA_sigmas_plus100
nuwro_genie_reco_MAs_prior_removed_plus100 = np.array([(dp * dp * x[i] - dx[i] * dx[i] * p) / (dp * dp - dx[i] * dx[i]) for i in range(len(x))])
nuwro_genie_reco_MA_sigmas_prior_removed_plus100 = np.array([(dp * dx[i]) / np.sqrt(dp * dp - dx[i] * dx[i]) for i in range(len(x))])

# %%
with open('trio_pickles/nuwro_fake_matrix_breakdown_3d.pkl', 'rb') as handle:
    tup = pickle.load(handle)

    prior_trio_matrix_breakdown, prior_cov_matrix_breakdown = tup[0], tup[1]
    nuwro_constrained_trio_matrix_breakdown, nuwro_constrained_trio_cov_matrix_breakdown = tup[2], tup[3]
    nuwro_asimov_constrained_trio_matrix_breakdown, nuwro_asimov_constrained_trio_cov_matrix_breakdown = tup[4], tup[5]
    nuwro_cov_mat_true_trios_matrix_breakdown, nuwro_cov_mat_trios_matrix_breakdown, nuwro_cov_mat_trio_covs_matrix_breakdown = tup[6], tup[7], tup[8]
    nuwro_xs_cov_mat_true_trios_matrix_breakdown, nuwro_xs_cov_mat_trios_matrix_breakdown, nuwro_xs_cov_mat_trio_covs_matrix_breakdown = tup[9], tup[10], tup[11]
    nuwro_genie_true_trios_matrix_breakdown, nuwro_genie_trios_matrix_breakdown, nuwro_genie_trio_covs_matrix_breakdown = tup[12], tup[13], tup[14]

nuwro_reco_MA_matrix_breakdown = nuwro_constrained_trio_matrix_breakdown[0]
nuwro_reco_MA_sigma_matrix_breakdown = np.sqrt(nuwro_constrained_trio_cov_matrix_breakdown[0,0])
x = nuwro_reco_MA_matrix_breakdown
dx = nuwro_reco_MA_sigma_matrix_breakdown
nuwro_reco_MA_prior_removed_matrix_breakdown = (dp * dp * x - dx * dx * p) / (dp * dp - dx * dx)
nuwro_reco_MA_sigma_prior_removed_matrix_breakdown = (dp * dx) / np.sqrt(dp * dp - dx * dx)

asimov_true_MA_matrix_breakdown = prior_trio_matrix_breakdown[0]
asimov_reco_MA_matrix_breakdown = nuwro_asimov_constrained_trio_matrix_breakdown[0]
asimov_reco_MA_sigma_matrix_breakdown = np.sqrt(nuwro_asimov_constrained_trio_cov_matrix_breakdown[0,0])
x = asimov_reco_MA_matrix_breakdown
dx = asimov_reco_MA_sigma_matrix_breakdown
asimov_reco_MA_prior_removed_matrix_breakdown = (dp * dp * x - dx * dx * p) / (dp * dp - dx * dx)
asimov_reco_MA_sigma_prior_removed_matrix_breakdown = (dp * dx) / np.sqrt(dp * dp - dx * dx)

nuwro_cov_mat_true_MAs_matrix_breakdown = np.array([x[0] for x in nuwro_cov_mat_true_trios_matrix_breakdown])
nuwro_cov_mat_reco_MAs_matrix_breakdown = np.array([x[0] for x in nuwro_cov_mat_trios_matrix_breakdown])
nuwro_cov_mat_reco_MA_sigmas_matrix_breakdown = [np.sqrt(x[0,0]) for x in nuwro_cov_mat_trio_covs_matrix_breakdown]
x = nuwro_cov_mat_reco_MAs_matrix_breakdown
dx = nuwro_cov_mat_reco_MA_sigmas_matrix_breakdown
nuwro_cov_mat_reco_MAs_prior_removed_matrix_breakdown = [(dp * dp * x[i] - dx[i] * dx[i] * p) / (dp * dp - dx[i] * dx[i]) for i in range(len(x))]
nuwro_cov_mat_reco_MA_sigmas_prior_removed_matrix_breakdown = [(dp * dx[i]) / np.sqrt(dp * dp - dx[i] * dx[i]) for i in range(len(x))]

nuwro_xs_cov_mat_true_MAs_matrix_breakdown = np.array([x[0] for x in nuwro_xs_cov_mat_true_trios_matrix_breakdown])
nuwro_xs_cov_mat_reco_MAs_matrix_breakdown = np.array([x[0] for x in nuwro_xs_cov_mat_trios_matrix_breakdown])
nuwro_xs_cov_mat_reco_MA_sigmas_matrix_breakdown = np.array([np.sqrt(x[0,0]) for x in nuwro_xs_cov_mat_trio_covs_matrix_breakdown])
x = nuwro_xs_cov_mat_reco_MAs_matrix_breakdown
dx = nuwro_xs_cov_mat_reco_MA_sigmas_matrix_breakdown
nuwro_xs_cov_mat_reco_MAs_prior_removed_matrix_breakdown = np.array([(dp * dp * x[i] - dx[i] * dx[i] * p) / (dp * dp - dx[i] * dx[i]) for i in range(len(x))])
nuwro_xs_cov_mat_reco_MA_sigmas_prior_removed_matrix_breakdown = np.array([(dp * dx[i]) / np.sqrt(dp * dp - dx[i] * dx[i]) for i in range(len(x))])

nuwro_genie_true_MAs_matrix_breakdown = np.array([x[0] for x in nuwro_genie_true_trios_matrix_breakdown])
nuwro_genie_reco_MAs_matrix_breakdown = np.array([x[0] for x in nuwro_genie_trios_matrix_breakdown])
nuwro_genie_reco_MA_sigmas_matrix_breakdown = np.array([np.sqrt(x[0,0]) for x in nuwro_genie_trio_covs_matrix_breakdown])
x = nuwro_genie_reco_MAs_matrix_breakdown
dx = nuwro_genie_reco_MA_sigmas_matrix_breakdown
nuwro_genie_reco_MAs_prior_removed_matrix_breakdown = np.array([(dp * dp * x[i] - dx[i] * dx[i] * p) / (dp * dp - dx[i] * dx[i]) for i in range(len(x))])
nuwro_genie_reco_MA_sigmas_prior_removed_matrix_breakdown = np.array([(dp * dx[i]) / np.sqrt(dp * dp - dx[i] * dx[i]) for i in range(len(x))])

# %%
with open('trio_pickles/genie_v2_fake_rate+shape_3d.pkl', 'rb') as handle:
    tup = pickle.load(handle)

    #trio_prior, prior_cov = tup[0], tup[1]
    genie_v2_constrained_trio, genie_v2_constrained_trio_cov = tup[2], tup[3]
    #asimov_constrained_trio, asimov_constrained_trio_cov = tup[4], tup[5]
    #genie_v2_cov_mat_true_trios, genie_v2_cov_mat_trios, genie_v2_cov_mat_trio_covs = tup[6], tup[7], tup[8]
    #genie_v2_xs_cov_mat_true_trios, genie_v2_xs_cov_mat_trios, genie_v2_xs_cov_mat_trio_covs = tup[9], tup[10], tup[11]
    #genie_v2_genie_true_trios, genie_v2_genie_trios, genie_v2_genie_trio_covs = tup[12], tup[13], tup[14]

genie_v2_reco_MA = genie_v2_constrained_trio[0]
genie_v2_reco_MA_sigma = np.sqrt(genie_v2_constrained_trio_cov[0,0])
x = genie_v2_reco_MA
dx = genie_v2_reco_MA_sigma
genie_v2_reco_MA_prior_removed = (dp * dp * x - dx * dx * p) / (dp * dp - dx * dx)
genie_v2_reco_MA_sigma_prior_removed = (dp * dx) / np.sqrt(dp * dp - dx * dx)

# %%
with open('trio_pickles/genie_v2_fake_+100_3d.pkl', 'rb') as handle:
    tup = pickle.load(handle)

    #trio_prior, prior_cov = tup[0], tup[1]
    genie_v2_constrained_trio_plus100, genie_v2_constrained_trio_cov_plus100 = tup[2], tup[3]
    #asimov_constrained_trio, asimov_constrained_trio_cov = tup[4], tup[5]
    #genie_v2_cov_mat_true_trios, genie_v2_cov_mat_trios, genie_v2_cov_mat_trio_covs = tup[6], tup[7], tup[8]
    #genie_v2_xs_cov_mat_true_trios, genie_v2_xs_cov_mat_trios, genie_v2_xs_cov_mat_trio_covs = tup[9], tup[10], tup[11]
    #genie_v2_genie_true_trios, genie_v2_genie_trios, genie_v2_genie_trio_covs = tup[12], tup[13], tup[14]

genie_v2_reco_MA_plus100 = genie_v2_constrained_trio_plus100[0]
genie_v2_reco_MA_sigma_plus100 = np.sqrt(genie_v2_constrained_trio_cov_plus100[0,0])
x = genie_v2_reco_MA_plus100
dx = genie_v2_reco_MA_sigma_plus100
genie_v2_reco_MA_prior_removed_plus100 = (dp * dp * x - dx * dx * p) / (dp * dp - dx * dx)
genie_v2_reco_MA_sigma_prior_removed_plus100 = (dp * dx) / np.sqrt(dp * dp - dx * dx)

with open('trio_pickles/genie_v2_fake_matrix_breakdown_3d.pkl', 'rb') as handle:
    tup = pickle.load(handle)

    #trio_prior, prior_cov = tup[0], tup[1]
    genie_v2_constrained_trio_matrix_breakdown, genie_v2_constrained_trio_cov_matrix_breakdown = tup[2], tup[3]
    #asimov_constrained_trio, asimov_constrained_trio_cov = tup[4], tup[5]
    #genie_v2_cov_mat_true_trios, genie_v2_cov_mat_trios, genie_v2_cov_mat_trio_covs = tup[6], tup[7], tup[8]
    #genie_v2_xs_cov_mat_true_trios, genie_v2_xs_cov_mat_trios, genie_v2_xs_cov_mat_trio_covs = tup[9], tup[10], tup[11]
    #genie_v2_genie_true_trios, genie_v2_genie_trios, genie_v2_genie_trio_covs = tup[12], tup[13], tup[14]
    

genie_v2_reco_MA_matrix_breakdown = genie_v2_constrained_trio_matrix_breakdown[0]
genie_v2_reco_MA_sigma_matrix_breakdown = np.sqrt(genie_v2_constrained_trio_cov_matrix_breakdown[0,0])
x = genie_v2_reco_MA_matrix_breakdown
dx = genie_v2_reco_MA_sigma_matrix_breakdown
genie_v2_reco_MA_prior_removed_matrix_breakdown = (dp * dp * x - dx * dx * p) / (dp * dp - dx * dx)
genie_v2_reco_MA_sigma_prior_removed_matrix_breakdown = (dp * dx) / np.sqrt(dp * dp - dx * dx)

# %% [markdown]
# # Normal Plots

# %%
plt.rcParams.update({'font.size': 9})
s = 20


plt.figure(figsize=(10,7))
plt.plot([0.7, 1.5], [0.7, 1.5], c="k", ls="dashed", lw=2, zorder=5)
plt.fill_between([0.7, 1.5], [prior_MA - prior_MA_sigma, prior_MA - prior_MA_sigma], [prior_MA + prior_MA_sigma, prior_MA + prior_MA_sigma], color="gray", alpha=0.2, label="GENIE Prior")

plt.scatter(nuwro_cov_mat_true_MAs, nuwro_cov_mat_reco_MAs, s=s, c="tab:blue", label="600 fake data sets\nfrom covariance matrix variations", zorder=0)
plt.errorbar(nuwro_cov_mat_true_MAs, nuwro_cov_mat_reco_MAs, yerr=nuwro_cov_mat_reco_MA_sigmas, c="tab:blue", fmt="none", capsize=4, lw=1, capthick=1, zorder=0)

plt.scatter(nuwro_xs_cov_mat_true_MAs, nuwro_xs_cov_mat_reco_MAs, s=s, c="tab:orange", label="600 fake data sets\nfrom CV with XS covariance matrix variations", zorder=1)
plt.errorbar(nuwro_xs_cov_mat_true_MAs, nuwro_xs_cov_mat_reco_MAs, yerr=nuwro_xs_cov_mat_reco_MA_sigmas, c="tab:orange", fmt="none", capsize=4, lw=1, capthick=1, zorder=1)

plt.scatter(nuwro_genie_true_MAs, nuwro_genie_reco_MAs, s=s, c="tab:green", label="600 fake data sets\nfrom CV with GENIE universe variations", zorder=1)
plt.errorbar(nuwro_genie_true_MAs, nuwro_genie_reco_MAs, yerr=nuwro_genie_reco_MA_sigmas, c="tab:green", fmt="none", capsize=4, lw=1, capthick=1, zorder=1)

plt.scatter(asimov_true_MA, asimov_reco_MA, s=30, label=f"Asimov fake data: {asimov_reco_MA:.3f} "r"$\pm$"f" {asimov_reco_MA_sigma:.3f} "
            r"$\mathrm{GeV/c^2}$"f"\n\t\t\tTrue: {asimov_true_MA:.3f} "r"$\mathrm{GeV/c^2}$""\n\t\t\t"
            fr"$\sigma = {np.abs(asimov_true_MA - asimov_reco_MA)/asimov_reco_MA_sigma:.3f}$"
            , c="tab:red", zorder=10)
plt.scatter(asimov_true_MA, asimov_reco_MA, s=70, c="k", zorder=9)
plt.errorbar(asimov_true_MA, asimov_reco_MA, yerr=asimov_reco_MA_sigma, fmt="none", c="tab:red", capthick=2, elinewidth=2, capsize=5, zorder=10)
plt.errorbar(asimov_true_MA, asimov_reco_MA, yerr=asimov_reco_MA_sigma, fmt="none", c="k", capthick=4, elinewidth=4, capsize=6, zorder=9)

plt.scatter(nuwro_fake_data_true_MA, nuwro_reco_MA, s=30, label=f"NuWro fake data: {nuwro_reco_MA:.3f} "r"$\pm$"f" {nuwro_reco_MA_sigma:.3f} "
            r"$\mathrm{GeV/c^2}$"f"\n\t\t\tTrue: {nuwro_fake_data_true_MA:.3f} "r"$\mathrm{GeV/c^2}$""\n\t\t\t"
            fr"$\sigma = {np.abs(nuwro_fake_data_true_MA - nuwro_reco_MA)/nuwro_reco_MA_sigma:.3f}$"
            , c="tab:brown", zorder=10)
plt.scatter(nuwro_fake_data_true_MA, nuwro_reco_MA, s=70, c="k", zorder=9)
plt.errorbar(nuwro_fake_data_true_MA, nuwro_reco_MA, yerr=nuwro_reco_MA_sigma, fmt="none", c="tab:brown", capthick=2, elinewidth=2, capsize=5, zorder=10)
plt.errorbar(nuwro_fake_data_true_MA, nuwro_reco_MA, yerr=nuwro_reco_MA_sigma, fmt="none", c="k", capthick=4, elinewidth=4, capsize=6, zorder=9)

plt.scatter(genie_v2_fake_data_true_MA, genie_v2_reco_MA, s=30, label=f"GENIE v2 fake data: {genie_v2_reco_MA:.3f} "r"$\pm$"f" {genie_v2_reco_MA_sigma:.3f} "
            r"$\mathrm{GeV/c^2}$"f"\n\t\t\tTrue: {genie_v2_fake_data_true_MA:.3f} "r"$\mathrm{GeV/c^2}$""\n\t\t\t"
            fr"$\sigma = {np.abs(genie_v2_fake_data_true_MA - genie_v2_reco_MA)/genie_v2_reco_MA_sigma:.3f}$"
            , c="tab:purple", zorder=10)
plt.scatter(genie_v2_fake_data_true_MA, genie_v2_reco_MA, s=70, c="k", zorder=9)
plt.errorbar(genie_v2_fake_data_true_MA, genie_v2_reco_MA, yerr=genie_v2_reco_MA_sigma, fmt="none", c="tab:purple", capthick=2, elinewidth=2, capsize=5, zorder=10)
plt.errorbar(genie_v2_fake_data_true_MA, genie_v2_reco_MA, yerr=genie_v2_reco_MA_sigma, fmt="none", c="k", capthick=4, elinewidth=4, capsize=6, zorder=9)

plt.legend(loc="upper left")
plt.xlabel(r"True $M_A$ (GeV/c$^2$)")
plt.ylabel(r"Reco $M_A$ Posterior (GeV/c$^2$)")
plt.xlim(0.7, 1.5)
plt.ylim(0.7, 1.5)
filename = "plots/normal"
plt.savefig(filename + ".png", facecolor="white", dpi=300)
plt.savefig(filename + ".jpg", facecolor="white", dpi=300)
plt.savefig(filename + ".svg", facecolor="white")



plt.figure(figsize=(10,7))
plt.plot([0.7, 1.5], [0.7, 1.5], c="k", ls="dashed", lw=2, zorder=5)

plt.scatter(nuwro_cov_mat_true_MAs, nuwro_cov_mat_reco_MAs_prior_removed, s=s, c="tab:blue", label="600 fake data sets\nfrom covariance matrix variations", zorder=0)
plt.errorbar(nuwro_cov_mat_true_MAs, nuwro_cov_mat_reco_MAs_prior_removed, yerr=nuwro_cov_mat_reco_MA_sigmas_prior_removed, c="tab:blue", fmt="none", capsize=4, lw=1, capthick=1, zorder=0)

plt.scatter(nuwro_xs_cov_mat_true_MAs, nuwro_xs_cov_mat_reco_MAs_prior_removed, s=s, c="tab:orange", label="600 fake data sets\nfrom CV with XS covariance matrix variations", zorder=1)
plt.errorbar(nuwro_xs_cov_mat_true_MAs, nuwro_xs_cov_mat_reco_MAs_prior_removed, yerr=nuwro_xs_cov_mat_reco_MA_sigmas_prior_removed, c="tab:orange", fmt="none", capsize=4, lw=1, capthick=1, zorder=1)

plt.scatter(nuwro_genie_true_MAs, nuwro_genie_reco_MAs_prior_removed, s=s, c="tab:green", label="600 fake data sets\nfrom CV with GENIE universe variations", zorder=1)
plt.errorbar(nuwro_genie_true_MAs, nuwro_genie_reco_MAs_prior_removed, yerr=nuwro_genie_reco_MA_sigmas_prior_removed, c="tab:green", fmt="none", capsize=4, lw=1, capthick=1, zorder=1)

plt.scatter(asimov_true_MA, asimov_reco_MA_prior_removed, s=30, label=f"Asimov fake data: {asimov_reco_MA_prior_removed:.3f} "
            r"$\pm$"f" {asimov_reco_MA_sigma_prior_removed:.3f} "
            r"$\mathrm{GeV/c^2}$"f"\n\t\t\tTrue: {asimov_true_MA:.3f} "r"$\mathrm{GeV/c^2}$""\n\t\t\t"
            fr"$\sigma = {np.abs(asimov_true_MA - asimov_reco_MA_prior_removed)/asimov_reco_MA_sigma_prior_removed:.3f}$"
            , c="tab:red", zorder=10)
plt.scatter(asimov_true_MA, asimov_reco_MA_prior_removed, s=70, c="k", zorder=9)
plt.errorbar(asimov_true_MA, asimov_reco_MA_prior_removed, yerr=asimov_reco_MA_sigma_prior_removed, fmt="none", c="tab:red", capthick=2, elinewidth=2, capsize=5, zorder=10)
plt.errorbar(asimov_true_MA, asimov_reco_MA_prior_removed, yerr=asimov_reco_MA_sigma_prior_removed, fmt="none", c="k", capthick=4, elinewidth=4, capsize=6, zorder=9)

plt.scatter(nuwro_fake_data_true_MA, nuwro_reco_MA_prior_removed, s=30, label=f"NuWro fake data: {nuwro_reco_MA_prior_removed:.3f} "
            r"$\pm$"f" {nuwro_reco_MA_sigma_prior_removed:.3f} "
            r"$\mathrm{GeV/c^2}$"f"\n\t\t\tTrue: {nuwro_fake_data_true_MA:.3f} "r"$\mathrm{GeV/c^2}$""\n\t\t\t"
            fr"$\sigma = {np.abs(nuwro_fake_data_true_MA - nuwro_reco_MA_prior_removed)/nuwro_reco_MA_sigma_prior_removed:.3f}$"
            , c="tab:brown", zorder=10)
plt.scatter(nuwro_fake_data_true_MA, nuwro_reco_MA_prior_removed, s=70, c="k", zorder=9)
plt.errorbar(nuwro_fake_data_true_MA, nuwro_reco_MA_prior_removed, yerr=nuwro_reco_MA_sigma_prior_removed, fmt="none", c="tab:brown", capthick=2, elinewidth=2, capsize=5, zorder=10)
plt.errorbar(nuwro_fake_data_true_MA, nuwro_reco_MA_prior_removed, yerr=nuwro_reco_MA_sigma_prior_removed, fmt="none", c="k", capthick=4, elinewidth=4, capsize=6, zorder=9)

plt.scatter(genie_v2_fake_data_true_MA, genie_v2_reco_MA_prior_removed, s=30, label=f"GENIE v2 fake data: {genie_v2_reco_MA_prior_removed:.3f} "
            r"$\pm$"f" {genie_v2_reco_MA_sigma_prior_removed:.3f} "
            r"$\mathrm{GeV/c^2}$"f"\n\t\t\tTrue: {genie_v2_fake_data_true_MA:.3f} "r"$\mathrm{GeV/c^2}$""\n\t\t\t"
            fr"$\sigma = {np.abs(genie_v2_fake_data_true_MA - genie_v2_reco_MA_prior_removed)/genie_v2_reco_MA_sigma_prior_removed:.3f}$"
            , c="tab:purple", zorder=10)
plt.scatter(genie_v2_fake_data_true_MA, genie_v2_reco_MA_prior_removed, s=70, c="k", zorder=9)
plt.errorbar(genie_v2_fake_data_true_MA, genie_v2_reco_MA_prior_removed, yerr=genie_v2_reco_MA_sigma_prior_removed, fmt="none", c="tab:purple", capthick=2, elinewidth=2, capsize=5, zorder=10)
plt.errorbar(genie_v2_fake_data_true_MA, genie_v2_reco_MA_prior_removed, yerr=genie_v2_reco_MA_sigma_prior_removed, fmt="none", c="k", capthick=4, elinewidth=4, capsize=6, zorder=9)

plt.legend(loc="upper left")
plt.xlabel(r"True $M_A$ (GeV/c$^2$)")
plt.ylabel(r"Reco $M_A$ (GeV/c$^2$)")
plt.xlim(0.7, 1.5)
plt.ylim(0.7, 1.5)
filename = "plots/normal_no_prior"
plt.savefig(filename + ".png", facecolor="white", dpi=300)
plt.savefig(filename + ".jpg", facecolor="white", dpi=300)
plt.savefig(filename + ".svg", facecolor="white")


plt.figure(figsize=(7,5))

bins = np.linspace(-5, 5, 21)
bin_width = bins[1] - bins[0]

plt.hist((nuwro_cov_mat_reco_MAs_prior_removed - nuwro_cov_mat_true_MAs) / nuwro_cov_mat_reco_MA_sigmas_prior_removed, bins=bins, histtype="step", lw=2, 
    label="600 fake data sets\nfrom covariance matrix variations")
plt.hist((nuwro_xs_cov_mat_reco_MAs_prior_removed - nuwro_xs_cov_mat_true_MAs) / nuwro_xs_cov_mat_reco_MA_sigmas_prior_removed, bins=bins, histtype="step", lw=2, 
    label="600 fake data sets\nfrom CV with XS covariance matrix variations")
plt.hist((nuwro_genie_reco_MAs_prior_removed - nuwro_genie_true_MAs) / nuwro_genie_reco_MA_sigmas_prior_removed, bins=bins, histtype="step", lw=2, 
    label="600 fake data sets\nfrom CV with GENIE universe variations")

x = np.linspace(-5, 5, 1000)
plt.plot(x, 600 * bin_width * np.exp(-0.5 * x * x) / np.sqrt(2 * np.pi), c="k", ls="dashed", lw=2, label="Gaussian with area = 600")

plt.ylabel("Number of Fake Data Universes")
plt.xlabel(r"Number of sigmas between reco and true $M_A$")
plt.legend()

plt.ylim(0, 400)

filename = "plots/fake_data_distribution"

plt.savefig(filename + ".png", facecolor="white", dpi=300)
plt.savefig(filename + ".jpg", facecolor="white", dpi=300)
plt.savefig(filename + ".svg", facecolor="white")

# %% [markdown]
# # Shape-only Plots

# %% [markdown]
# ## +100%

# %%
plt.rcParams.update({'font.size': 7})


plt.figure(figsize=(10,7))
plt.plot([0.7, 1.5], [0.7, 1.5], c="k", ls="dashed", lw=2, zorder=5)
plt.fill_between([0.7, 1.5], [prior_MA - prior_MA_sigma, prior_MA - prior_MA_sigma], [prior_MA + prior_MA_sigma, prior_MA + prior_MA_sigma], color="gray", alpha=0.2, label="GENIE Prior")

plt.scatter(nuwro_cov_mat_true_MAs_plus100, nuwro_cov_mat_reco_MAs_plus100, s=s, c="tab:blue", label="600 fake data sets\nfrom covariance matrix variations", zorder=0)
plt.errorbar(nuwro_cov_mat_true_MAs_plus100, nuwro_cov_mat_reco_MAs_plus100, yerr=nuwro_cov_mat_reco_MA_sigmas_plus100, c="tab:blue", fmt="none", capsize=4, lw=1, capthick=1, zorder=0)

plt.scatter(nuwro_xs_cov_mat_true_MAs_plus100, nuwro_xs_cov_mat_reco_MAs_plus100, s=s, c="tab:orange", label="600 fake data sets\nfrom CV with XS covariance matrix variations", zorder=1)
plt.errorbar(nuwro_xs_cov_mat_true_MAs_plus100, nuwro_xs_cov_mat_reco_MAs_plus100, yerr=nuwro_xs_cov_mat_reco_MA_sigmas_plus100, c="tab:orange", fmt="none", capsize=4, lw=1, capthick=1, zorder=1)

plt.scatter(nuwro_genie_true_MAs_plus100, nuwro_genie_reco_MAs_plus100, s=s, c="tab:green", label="600 fake data sets\nfrom CV with GENIE universe variations", zorder=1)
plt.errorbar(nuwro_genie_true_MAs_plus100, nuwro_genie_reco_MAs_plus100, yerr=nuwro_genie_reco_MA_sigmas_plus100, c="tab:green", fmt="none", capsize=4, lw=1, capthick=1, zorder=1)

plt.scatter(asimov_true_MA_plus100, asimov_reco_MA_plus100, s=30, label=f"Asimov fake data: {asimov_reco_MA_plus100:.3f} "r"$\pm$"f" {asimov_reco_MA_sigma_plus100:.3f} "
            r"$\mathrm{GeV/c^2}$"f"\n\t\t\tTrue: {asimov_true_MA_plus100:.3f} "r"$\mathrm{GeV/c^2}$""\n\t\t\t"
            fr"$\sigma = {np.abs(asimov_true_MA_plus100 - asimov_reco_MA_plus100)/asimov_reco_MA_sigma_plus100:.3f}$"
            , c="tab:red", zorder=10)
plt.scatter(asimov_true_MA_plus100, asimov_reco_MA_plus100, s=70, c="k", zorder=9)
plt.errorbar(asimov_true_MA_plus100, asimov_reco_MA_plus100, yerr=asimov_reco_MA_sigma_plus100, fmt="none", c="tab:red", capthick=2, elinewidth=2, capsize=5, zorder=10)
plt.errorbar(asimov_true_MA_plus100, asimov_reco_MA_plus100, yerr=asimov_reco_MA_sigma_plus100, fmt="none", c="k", capthick=4, elinewidth=4, capsize=6, zorder=9)

plt.scatter(nuwro_fake_data_true_MA, nuwro_reco_MA_plus100, s=30, label=f"NuWro fake data: {nuwro_reco_MA_plus100:.3f} "r"$\pm$"f" {nuwro_reco_MA_sigma_plus100:.3f} "
            r"$\mathrm{GeV/c^2}$"f"\n\t\t\tTrue: {nuwro_fake_data_true_MA:.3f} "r"$\mathrm{GeV/c^2}$""\n\t\t\t"
            fr"$\sigma = {np.abs(nuwro_fake_data_true_MA - nuwro_reco_MA_plus100)/nuwro_reco_MA_sigma_plus100:.3f}$"
            , c="tab:brown", zorder=10)
plt.scatter(nuwro_fake_data_true_MA, nuwro_reco_MA_plus100, s=70, c="k", zorder=9)
plt.errorbar(nuwro_fake_data_true_MA, nuwro_reco_MA_plus100, yerr=nuwro_reco_MA_sigma_plus100, fmt="none", c="tab:brown", capthick=2, elinewidth=2, capsize=5, zorder=10)
plt.errorbar(nuwro_fake_data_true_MA, nuwro_reco_MA_plus100, yerr=nuwro_reco_MA_sigma_plus100, fmt="none", c="k", capthick=4, elinewidth=4, capsize=6, zorder=9)

plt.scatter(genie_v2_fake_data_true_MA, genie_v2_reco_MA_plus100, s=30, label=f"GENIE v2 fake data: {genie_v2_reco_MA_plus100:.3f} "r"$\pm$"f" {genie_v2_reco_MA_sigma_plus100:.3f} "
            r"$\mathrm{GeV/c^2}$"f"\n\t\t\tTrue: {genie_v2_fake_data_true_MA:.3f} "r"$\mathrm{GeV/c^2}$""\n\t\t\t"
            fr"$\sigma = {np.abs(genie_v2_fake_data_true_MA - genie_v2_reco_MA_plus100)/genie_v2_reco_MA_sigma_plus100:.3f}$"
            , c="tab:purple", zorder=10)
plt.scatter(genie_v2_fake_data_true_MA, genie_v2_reco_MA_plus100, s=70, c="k", zorder=9)
plt.errorbar(genie_v2_fake_data_true_MA, genie_v2_reco_MA_plus100, yerr=genie_v2_reco_MA_sigma_plus100, fmt="none", c="tab:purple", capthick=2, elinewidth=2, capsize=5, zorder=10)
plt.errorbar(genie_v2_fake_data_true_MA, genie_v2_reco_MA_plus100, yerr=genie_v2_reco_MA_sigma_plus100, fmt="none", c="k", capthick=4, elinewidth=4, capsize=6, zorder=9)

plt.legend(loc="upper left")
plt.xlabel(r"True $M_A$ (GeV/c$^2$)")
plt.ylabel(r"Reco $M_A$ Posterior (GeV/c$^2$)")
plt.xlim(0.7, 1.5)
plt.ylim(0.4, 1.5)
plt.title("Shape-Only (+100%)")

filename = "plots/plus100"
plt.savefig(filename + ".png", facecolor="white", dpi=300)
plt.savefig(filename + ".jpg", facecolor="white", dpi=300)
plt.savefig(filename + ".svg", facecolor="white")



plt.figure(figsize=(10,7))
plt.plot([0.7, 1.5], [0.7, 1.5], c="k", ls="dashed", lw=2, zorder=5)

plt.scatter(nuwro_cov_mat_true_MAs_plus100, nuwro_cov_mat_reco_MAs_prior_removed_plus100, s=s, c="tab:blue", label="600 fake data sets\nfrom covariance matrix variations", zorder=0)
plt.errorbar(nuwro_cov_mat_true_MAs_plus100, nuwro_cov_mat_reco_MAs_prior_removed_plus100, yerr=nuwro_cov_mat_reco_MA_sigmas_prior_removed_plus100, c="tab:blue", fmt="none", capsize=4, lw=1, capthick=1, zorder=0)

plt.scatter(nuwro_xs_cov_mat_true_MAs_plus100, nuwro_xs_cov_mat_reco_MAs_prior_removed_plus100, s=s, c="tab:orange", label="600 fake data sets\nfrom CV with XS covariance matrix variations", zorder=1)
plt.errorbar(nuwro_xs_cov_mat_true_MAs_plus100, nuwro_xs_cov_mat_reco_MAs_prior_removed_plus100, yerr=nuwro_xs_cov_mat_reco_MA_sigmas_prior_removed_plus100, c="tab:orange", fmt="none", capsize=4, lw=1, capthick=1, zorder=1)

plt.scatter(nuwro_genie_true_MAs_plus100, nuwro_genie_reco_MAs_prior_removed_plus100, s=s, c="tab:green", label="600 fake data sets\nfrom CV with GENIE universe variations", zorder=1)
plt.errorbar(nuwro_genie_true_MAs_plus100, nuwro_genie_reco_MAs_prior_removed_plus100, yerr=nuwro_genie_reco_MA_sigmas_prior_removed_plus100, c="tab:green", fmt="none", capsize=4, lw=1, capthick=1, zorder=1)

plt.scatter(asimov_true_MA_plus100, asimov_reco_MA_prior_removed_plus100, s=30, label=f"Asimov fake data: {asimov_reco_MA_prior_removed_plus100:.3f} "r"$\pm$"f" {asimov_reco_MA_sigma_prior_removed_plus100:.3f} "
            r"$\mathrm{GeV/c^2}$"f"\n\t\t\tTrue: {asimov_true_MA_plus100:.3f} "r"$\mathrm{GeV/c^2}$""\n\t\t\t"
            fr"$\sigma = {np.abs(asimov_true_MA_plus100 - asimov_reco_MA_prior_removed_plus100)/asimov_reco_MA_sigma_prior_removed_plus100:.3f}$"
            , c="tab:red", zorder=10)
plt.scatter(asimov_true_MA_plus100, asimov_reco_MA_prior_removed_plus100, s=70, c="k", zorder=9)
plt.errorbar(asimov_true_MA_plus100, asimov_reco_MA_prior_removed_plus100, yerr=asimov_reco_MA_sigma_prior_removed_plus100, fmt="none", c="tab:red", capthick=2, elinewidth=2, capsize=5, zorder=10)
plt.errorbar(asimov_true_MA_plus100, asimov_reco_MA_prior_removed_plus100, yerr=asimov_reco_MA_sigma_prior_removed_plus100, fmt="none", c="k", capthick=4, elinewidth=4, capsize=6, zorder=9)

plt.scatter(nuwro_fake_data_true_MA, nuwro_reco_MA_prior_removed_plus100, s=30, label=f"NuWro fake data: {nuwro_reco_MA_prior_removed_plus100:.3f} "r"$\pm$"f" {nuwro_reco_MA_sigma_prior_removed_plus100:.3f} "
            r"$\mathrm{GeV/c^2}$"f"\n\t\t\tTrue: {nuwro_fake_data_true_MA:.3f} "r"$\mathrm{GeV/c^2}$""\n\t\t\t"
            fr"$\sigma = {np.abs(nuwro_fake_data_true_MA - nuwro_reco_MA_prior_removed_plus100)/nuwro_reco_MA_sigma_prior_removed_plus100:.3f}$"
            , c="tab:brown", zorder=10)
plt.scatter(nuwro_fake_data_true_MA, nuwro_reco_MA_prior_removed_plus100, s=70, c="k", zorder=9)
plt.errorbar(nuwro_fake_data_true_MA, nuwro_reco_MA_prior_removed_plus100, yerr=nuwro_reco_MA_sigma_prior_removed_plus100, fmt="none", c="tab:brown", capthick=2, elinewidth=2, capsize=5, zorder=10)
plt.errorbar(nuwro_fake_data_true_MA, nuwro_reco_MA_prior_removed_plus100, yerr=nuwro_reco_MA_sigma_prior_removed_plus100, fmt="none", c="k", capthick=4, elinewidth=4, capsize=6, zorder=9)

plt.scatter(genie_v2_fake_data_true_MA, genie_v2_reco_MA_prior_removed_plus100, s=30, label=f"GENIE v2 fake data: {genie_v2_reco_MA_prior_removed_plus100:.3f} "
            r"$\pm$"f" {genie_v2_reco_MA_sigma_prior_removed_plus100:.3f} "r"$\mathrm{GeV/c^2}$"f"\n\t\t\tTrue: {genie_v2_fake_data_true_MA:.3f} "r"$\mathrm{GeV/c^2}$""\n\t\t\t"
            fr"$\sigma = {np.abs(genie_v2_fake_data_true_MA - genie_v2_reco_MA_prior_removed_plus100)/genie_v2_reco_MA_sigma_prior_removed_plus100:.3f}$"
            , c="tab:purple", zorder=10)
plt.scatter(genie_v2_fake_data_true_MA, genie_v2_reco_MA_prior_removed_plus100, s=70, c="k", zorder=9)
plt.errorbar(genie_v2_fake_data_true_MA, genie_v2_reco_MA_prior_removed_plus100, yerr=genie_v2_reco_MA_sigma_prior_removed_plus100, fmt="none", c="tab:purple", capthick=2, elinewidth=2, capsize=5, zorder=10)
plt.errorbar(genie_v2_fake_data_true_MA, genie_v2_reco_MA_prior_removed_plus100, yerr=genie_v2_reco_MA_sigma_prior_removed_plus100, fmt="none", c="k", capthick=4, elinewidth=4, capsize=6, zorder=9)

plt.legend(loc="upper left")
plt.xlabel(r"True $M_A$ (GeV/c$^2$)")
plt.ylabel(r"Reco $M_A$ (GeV/c$^2$)")
plt.xlim(0.7, 1.5)
plt.ylim(0.4, 1.5)
plt.title("Shape-Only (+100%)")

filename = "plots/plus100_no_prior"
plt.savefig(filename + ".png", facecolor="white", dpi=300)
plt.savefig(filename + ".jpg", facecolor="white", dpi=300)
plt.savefig(filename + ".svg", facecolor="white")

# %% [markdown]
# ## Matrix Breakdown

# %%
plt.rcParams.update({'font.size': 7})


plt.figure(figsize=(10,7))
plt.plot([0.7, 1.5], [0.7, 1.5], c="k", ls="dashed", lw=2, zorder=5)
plt.fill_between([0.7, 1.5], [prior_MA - prior_MA_sigma, prior_MA - prior_MA_sigma], [prior_MA + prior_MA_sigma, prior_MA + prior_MA_sigma], color="gray", alpha=0.2, label="GENIE Prior")

plt.scatter(nuwro_cov_mat_true_MAs_matrix_breakdown, nuwro_cov_mat_reco_MAs_matrix_breakdown, s=s, c="tab:blue", label="600 fake data sets\nfrom covariance matrix variations", zorder=0)
plt.errorbar(nuwro_cov_mat_true_MAs_matrix_breakdown, nuwro_cov_mat_reco_MAs_matrix_breakdown, yerr=nuwro_cov_mat_reco_MA_sigmas_matrix_breakdown, c="tab:blue", fmt="none", capsize=4, lw=1, capthick=1, zorder=0)

plt.scatter(nuwro_xs_cov_mat_true_MAs_matrix_breakdown, nuwro_xs_cov_mat_reco_MAs_matrix_breakdown, s=s, c="tab:orange", label="600 fake data sets\nfrom CV with XS covariance matrix variations", zorder=1)
plt.errorbar(nuwro_xs_cov_mat_true_MAs_matrix_breakdown, nuwro_xs_cov_mat_reco_MAs_matrix_breakdown, yerr=nuwro_xs_cov_mat_reco_MA_sigmas_matrix_breakdown, c="tab:orange", fmt="none", capsize=4, lw=1, capthick=1, zorder=1)

plt.scatter(nuwro_genie_true_MAs_matrix_breakdown, nuwro_genie_reco_MAs_matrix_breakdown, s=s, c="tab:green", label="600 fake data sets\nfrom CV with GENIE universe variations", zorder=1)
plt.errorbar(nuwro_genie_true_MAs_matrix_breakdown, nuwro_genie_reco_MAs_matrix_breakdown, yerr=nuwro_genie_reco_MA_sigmas_matrix_breakdown, c="tab:green", fmt="none", capsize=4, lw=1, capthick=1, zorder=1)

plt.scatter(asimov_true_MA, asimov_reco_MA, s=30, label=f"Asimov fake data: {asimov_reco_MA:.3f} "r"$\pm$"f" {asimov_reco_MA_sigma:.3f} "
            r"$\mathrm{GeV/c^2}$"f"\n\t\t\tTrue: {asimov_true_MA:.3f} "r"$\mathrm{GeV/c^2}$""\n\t\t\t"
            fr"$\sigma = {np.abs(asimov_true_MA - asimov_reco_MA)/asimov_reco_MA_sigma:.3f}$"
            , c="tab:red", zorder=10)
plt.scatter(asimov_true_MA, asimov_reco_MA, s=70, c="k", zorder=9)
plt.errorbar(asimov_true_MA, asimov_reco_MA, yerr=asimov_reco_MA_sigma, fmt="none", c="tab:red", capthick=2, elinewidth=2, capsize=5, zorder=10)
plt.errorbar(asimov_true_MA, asimov_reco_MA, yerr=asimov_reco_MA_sigma, fmt="none", c="k", capthick=4, elinewidth=4, capsize=6, zorder=9)

plt.scatter(nuwro_fake_data_true_MA, nuwro_reco_MA, s=30, label=f"NuWro fake data: {nuwro_reco_MA:.3f} "r"$\pm$"f" {nuwro_reco_MA_sigma:.3f} "
            r"$\mathrm{GeV/c^2}$"f"\n\t\t\tTrue: {nuwro_fake_data_true_MA:.3f} "r"$\mathrm{GeV/c^2}$""\n\t\t\t"
            fr"$\sigma = {np.abs(nuwro_fake_data_true_MA - nuwro_reco_MA)/nuwro_reco_MA_sigma:.3f}$"
            , c="tab:brown", zorder=10)
plt.scatter(nuwro_fake_data_true_MA, nuwro_reco_MA, s=70, c="k", zorder=9)
plt.errorbar(nuwro_fake_data_true_MA, nuwro_reco_MA, yerr=nuwro_reco_MA_sigma, fmt="none", c="tab:brown", capthick=2, elinewidth=2, capsize=5, zorder=10)
plt.errorbar(nuwro_fake_data_true_MA, nuwro_reco_MA, yerr=nuwro_reco_MA_sigma, fmt="none", c="k", capthick=4, elinewidth=4, capsize=6, zorder=9)

plt.scatter(genie_v2_fake_data_true_MA, genie_v2_reco_MA, s=30, label=f"GENIE v2 fake data: {genie_v2_reco_MA:.3f} "r"$\pm$"f" {genie_v2_reco_MA_sigma:.3f} "
            r"$\mathrm{GeV/c^2}$"f"\n\t\t\tTrue: {genie_v2_fake_data_true_MA:.3f} "r"$\mathrm{GeV/c^2}$""\n\t\t\t"
            fr"$\sigma = {np.abs(genie_v2_fake_data_true_MA - genie_v2_reco_MA)/genie_v2_reco_MA_sigma:.3f}$"
            , c="tab:purple", zorder=10)
plt.scatter(genie_v2_fake_data_true_MA, genie_v2_reco_MA, s=70, c="k", zorder=9)
plt.errorbar(genie_v2_fake_data_true_MA, genie_v2_reco_MA, yerr=genie_v2_reco_MA_sigma, fmt="none", c="tab:purple", capthick=2, elinewidth=2, capsize=5, zorder=10)
plt.errorbar(genie_v2_fake_data_true_MA, genie_v2_reco_MA, yerr=genie_v2_reco_MA_sigma, fmt="none", c="k", capthick=4, elinewidth=4, capsize=6, zorder=9)

plt.legend(loc="upper left")
plt.xlabel(r"True $M_A$ (GeV/c$^2$)")
plt.ylabel(r"Reco $M_A$ Posterior (GeV/c$^2$)")
plt.xlim(0.7, 1.5)
plt.ylim(0.5, 1.5)
plt.title("Shape-Only (Matrix Breakdown)")
filename = "plots/matrix_breakdown"
plt.savefig(filename + ".png", facecolor="white", dpi=300)
plt.savefig(filename + ".jpg", facecolor="white", dpi=300)
plt.savefig(filename + ".svg", facecolor="white")


plt.figure(figsize=(10,7))
plt.plot([0.7, 1.5], [0.7, 1.5], c="k", ls="dashed", lw=2, zorder=5)

plt.scatter(nuwro_cov_mat_true_MAs_matrix_breakdown, nuwro_cov_mat_reco_MAs_prior_removed_matrix_breakdown, s=s, c="tab:blue", label="600 fake data sets\nfrom covariance matrix variations", zorder=0)
plt.errorbar(nuwro_cov_mat_true_MAs_matrix_breakdown, nuwro_cov_mat_reco_MAs_prior_removed_matrix_breakdown, yerr=nuwro_cov_mat_reco_MA_sigmas_prior_removed_matrix_breakdown, c="tab:blue", fmt="none", capsize=4, lw=1, capthick=1, zorder=0)

plt.scatter(nuwro_xs_cov_mat_true_MAs_matrix_breakdown, nuwro_xs_cov_mat_reco_MAs_prior_removed_matrix_breakdown, s=s, c="tab:orange", label="600 fake data sets\nfrom CV with XS covariance matrix variations", zorder=1)
plt.errorbar(nuwro_xs_cov_mat_true_MAs_matrix_breakdown, nuwro_xs_cov_mat_reco_MAs_prior_removed_matrix_breakdown, yerr=nuwro_xs_cov_mat_reco_MA_sigmas_prior_removed_matrix_breakdown, c="tab:orange", fmt="none", capsize=4, lw=1, capthick=1, zorder=1)

plt.scatter(nuwro_genie_true_MAs_matrix_breakdown, nuwro_genie_reco_MAs_prior_removed_matrix_breakdown, s=s, c="tab:green", label="600 fake data sets\nfrom CV with GENIE universe variations", zorder=1)
plt.errorbar(nuwro_genie_true_MAs_matrix_breakdown, nuwro_genie_reco_MAs_prior_removed_matrix_breakdown, yerr=nuwro_genie_reco_MA_sigmas_prior_removed_matrix_breakdown, c="tab:green", fmt="none", capsize=4, lw=1, capthick=1, zorder=1)

plt.scatter(asimov_true_MA_matrix_breakdown, asimov_reco_MA_prior_removed_matrix_breakdown, s=30, label=f"Asimov fake data: {asimov_reco_MA_prior_removed_matrix_breakdown:.3f} "
            r"$\pm$"f" {asimov_reco_MA_sigma_prior_removed_matrix_breakdown:.3f} "r"$\mathrm{GeV/c^2}$"f"\n\t\t\tTrue: {asimov_true_MA_matrix_breakdown:.3f} "r"$\mathrm{GeV/c^2}$""\n\t\t\t"
            fr"$\sigma = {np.abs(asimov_true_MA_matrix_breakdown - asimov_reco_MA_prior_removed_matrix_breakdown)/asimov_reco_MA_sigma_prior_removed_matrix_breakdown:.3f}$"
            , c="tab:red", zorder=10)
plt.scatter(asimov_true_MA_matrix_breakdown, asimov_reco_MA_prior_removed_matrix_breakdown, s=70, c="k", zorder=9)
plt.errorbar(asimov_true_MA_matrix_breakdown, asimov_reco_MA_prior_removed_matrix_breakdown, yerr=asimov_reco_MA_sigma_prior_removed_matrix_breakdown, fmt="none", c="tab:red", capthick=2, elinewidth=2, capsize=5, zorder=10)
plt.errorbar(asimov_true_MA_matrix_breakdown, asimov_reco_MA_prior_removed_matrix_breakdown, yerr=asimov_reco_MA_sigma_prior_removed_matrix_breakdown, fmt="none", c="k", capthick=4, elinewidth=4, capsize=6, zorder=9)

plt.scatter(nuwro_fake_data_true_MA, nuwro_reco_MA_prior_removed_matrix_breakdown, s=30, label=f"NuWro fake data: {nuwro_reco_MA_prior_removed_matrix_breakdown:.3f} "
            r"$\pm$"f" {nuwro_reco_MA_sigma_prior_removed_matrix_breakdown:.3f} "r"$\mathrm{GeV/c^2}$"f"\n\t\t\tTrue: {nuwro_fake_data_true_MA:.3f} "r"$\mathrm{GeV/c^2}$""\n\t\t\t"
            fr"$\sigma = {np.abs(nuwro_fake_data_true_MA - nuwro_reco_MA_prior_removed_matrix_breakdown)/nuwro_reco_MA_sigma_prior_removed_matrix_breakdown:.3f}$"
            , c="tab:brown", zorder=10)
plt.scatter(nuwro_fake_data_true_MA, nuwro_reco_MA_prior_removed_matrix_breakdown, s=70, c="k", zorder=9)
plt.errorbar(nuwro_fake_data_true_MA, nuwro_reco_MA_prior_removed_matrix_breakdown, yerr=nuwro_reco_MA_sigma_prior_removed_matrix_breakdown, fmt="none", c="tab:brown", capthick=2, elinewidth=2, capsize=5, zorder=10)
plt.errorbar(nuwro_fake_data_true_MA, nuwro_reco_MA_prior_removed_matrix_breakdown, yerr=nuwro_reco_MA_sigma_prior_removed_matrix_breakdown, fmt="none", c="k", capthick=4, elinewidth=4, capsize=6, zorder=9)

plt.scatter(genie_v2_fake_data_true_MA, genie_v2_reco_MA_prior_removed_matrix_breakdown, s=30, label=f"GENIE v2 fake data: {genie_v2_reco_MA_prior_removed_matrix_breakdown:.3f} "
            r"$\pm$"f" {genie_v2_reco_MA_sigma_prior_removed_matrix_breakdown:.3f} "r"$\mathrm{GeV/c^2}$"f"\n\t\t\tTrue: {genie_v2_fake_data_true_MA:.3f} "r"$\mathrm{GeV/c^2}$""\n\t\t\t"
            fr"$\sigma = {np.abs(genie_v2_fake_data_true_MA - genie_v2_reco_MA_prior_removed_matrix_breakdown)/genie_v2_reco_MA_sigma_prior_removed_matrix_breakdown:.3f}$"
            , c="tab:purple", zorder=10)
plt.scatter(genie_v2_fake_data_true_MA, genie_v2_reco_MA_prior_removed_matrix_breakdown, s=70, c="k", zorder=9)
plt.errorbar(genie_v2_fake_data_true_MA, genie_v2_reco_MA_prior_removed_matrix_breakdown, yerr=genie_v2_reco_MA_sigma_prior_removed_matrix_breakdown, fmt="none", c="tab:purple", capthick=2, elinewidth=2, capsize=5, zorder=10)
plt.errorbar(genie_v2_fake_data_true_MA, genie_v2_reco_MA_prior_removed_matrix_breakdown, yerr=genie_v2_reco_MA_sigma_prior_removed_matrix_breakdown, fmt="none", c="k", capthick=4, elinewidth=4, capsize=6, zorder=9)

plt.legend(loc="upper left")
plt.xlabel(r"True $M_A$ (GeV/c$^2$)")
plt.ylabel(r"Reco $M_A$ (GeV/c^2$)")
plt.xlim(0.7, 1.5)
plt.ylim(0.5, 1.5)
plt.title("Shape-Only (Matrix Breakdown)")
filename = "plots/matrix_breakdown_no_prior"
plt.savefig(filename + ".png", facecolor="white", dpi=300)
plt.savefig(filename + ".jpg", facecolor="white", dpi=300)
plt.savefig(filename + ".svg", facecolor="white")

# %% [markdown]
# # MA vs MEC Plots

# %%
def get_ellipse_x_y_points_from_pair_cov(pair, cov, sigma=2):

    eigenvals, eigenvecs = np.linalg.eig(cov)

    # From https://numpy.org/doc/stable/reference/generated/numpy.linalg.eig.html: 
    # The normalized (unit “length”) eigenvectors, such that the column eigenvectors[:,i] is the eigenvector corresponding to the eigenvalue eigenvalues[i].
    eigenvecs = np.transpose(eigenvecs) 

    t = np.linspace(0, 2*np.pi, 100)

    ellipse_points_x = (np.cos(t) * sigma * np.sqrt(eigenvals[0]) * eigenvecs[0][1] + pair[1]
                    + np.sin(t) * sigma * np.sqrt(eigenvals[1]) * eigenvecs[1][1])
    ellpise_points_y = (np.cos(t) * sigma * np.sqrt(eigenvals[0]) * eigenvecs[0][0] + pair[0]
                    + np.sin(t) * sigma * np.sqrt(eigenvals[1]) * eigenvecs[1][0])


    return ellipse_points_x, ellpise_points_y

# %%
prior_pair = prior_trio[:-1]
prior_pair_cov = prior_cov[:-1,:-1]

nuwro_pair = nuwro_constrained_trio[:-1]
nuwro_pair_cov = nuwro_constrained_trio_cov[:-1,:-1]

genie_v2_pair = genie_v2_constrained_trio[:-1]
genie_v2_pair_cov = genie_v2_constrained_trio_cov[:-1,:-1]


plt.rcParams.update({'font.size': 14})
plt.rcParams['lines.linewidth'] = 3

plt.figure(figsize=(10,7))

plt.scatter(prior_pair[-1], prior_pair[-2], marker="*", s=200, label=f"Prior best-fit, (1.66, 1.1)", edgecolors="k", c="tab:blue")
x, y = get_ellipse_x_y_points_from_pair_cov(prior_pair, prior_pair_cov, sigma=2)
plt.plot(x, y, label="Prior 2$\sigma$ Ellipse", c="tab:blue")

plt.scatter(nuwro_pair[-1], nuwro_pair[-2], marker="*", s=200, label=f"NuWro Fake Data Posterior best-fit, ({nuwro_pair[-1]:.2f}, {nuwro_pair[-2]:.2f})", edgecolors="k", c="tab:orange")
x, y = get_ellipse_x_y_points_from_pair_cov(nuwro_pair, nuwro_pair_cov, sigma=2)
plt.plot(x, y, label="NuWro Fake Data Posterior 2$\sigma$ Ellipse", c="tab:orange")

plt.scatter(genie_v2_pair[-1], genie_v2_pair[-2], marker="*", s=200, label=f"GENIE v2 Fake Data Posterior best-fit, ({genie_v2_pair[-1]:.2f}, {genie_v2_pair[-2]:.2f})", edgecolors="k", c="tab:green")
x, y = get_ellipse_x_y_points_from_pair_cov(genie_v2_pair, genie_v2_pair_cov, sigma=2)
plt.plot(x, y, label="GENIE v2 Fake Data Posterior 2$\sigma$ Ellipse", c="tab:green")


plt.xlabel(r"NormCCMEC")
plt.ylabel(r"$M_A$ (GeV/c$^2$)")

lgnd = plt.legend()
lgnd.legend_handles[0]._sizes = [50]
lgnd.legend_handles[1]._sizes = [50]

plt.ylim((0.5, 2))
filename = "plots/MA_MEC"
plt.savefig(filename + ".png", facecolor="white", dpi=300)
plt.savefig(filename + ".jpg", facecolor="white", dpi=300)
plt.savefig(filename + ".svg", facecolor="white")

# %% [markdown]
# # MA vs Lambda Plots

# %%
with open('trio_pickles/nuwro_fake_+100_3d.pkl', 'rb') as handle:
    tup = pickle.load(handle)
    #prior_trio, prior_cov = tup[0], tup[1]
    nuwro_plus100_constrained_trio, nuwro_plus100_constrained_trio_cov = tup[2], tup[3]
    #nuwro_asimov_constrained_trio, nuwro_asimov_constrained_trio_cov = tup[4], tup[5]
    #nuwro_cov_mat_true_trios, nuwro_cov_mat_trios, nuwro_cov_mat_trio_covs = tup[6], tup[7], tup[8]
    #nuwro_xs_cov_mat_true_trios, nuwro_xs_cov_mat_trios, nuwro_xs_cov_mat_trio_covs = tup[9], tup[10], tup[11]
    #nuwro_genie_true_trios, nuwro_genie_trios, nuwro_genie_trio_covs = tup[12], tup[13], tup[14]

with open('trio_pickles/nuwro_fake_matrix_breakdown_3d.pkl', 'rb') as handle:
    tup = pickle.load(handle)
    #prior_trio, prior_cov = tup[0], tup[1]
    nuwro_matrix_breakdown_constrained_trio, nuwro_matrix_breakdown_constrained_trio_cov = tup[2], tup[3]
    #nuwro_asimov_constrained_trio, nuwro_asimov_constrained_trio_cov = tup[4], tup[5]
    #nuwro_cov_mat_true_trios, nuwro_cov_mat_trios, nuwro_cov_mat_trio_covs = tup[6], tup[7], tup[8]
    #nuwro_xs_cov_mat_true_trios, nuwro_xs_cov_mat_trios, nuwro_xs_cov_mat_trio_covs = tup[9], tup[10], tup[11]
    #nuwro_genie_true_trios, nuwro_genie_trios, nuwro_genie_trio_covs = tup[12], tup[13], tup[14]

with open('trio_pickles/genie_v2_fake_+100_3d.pkl', 'rb') as handle:
    tup = pickle.load(handle)
    #trio_prior, prior_cov = tup[0], tup[1]
    genie_v2_plus100_constrained_trio, genie_v2_plus100_constrained_trio_cov = tup[2], tup[3]
    #asimov_constrained_trio, asimov_constrained_trio_cov = tup[4], tup[5]
    #genie_v2_cov_mat_true_trios, genie_v2_cov_mat_trios, genie_v2_cov_mat_trio_covs = tup[6], tup[7], tup[8]
    #genie_v2_xs_cov_mat_true_trios, genie_v2_xs_cov_mat_trios, genie_v2_xs_cov_mat_trio_covs = tup[9], tup[10], tup[11]
    #genie_v2_genie_true_trios, genie_v2_genie_trios, genie_v2_genie_trio_covs = tup[12], tup[13], tup[14]

with open('trio_pickles/genie_v2_fake_matrix_breakdown_3d.pkl', 'rb') as handle:
    tup = pickle.load(handle)
    #trio_prior, prior_cov = tup[0], tup[1]
    genie_v2_matrix_breakdown_constrained_trio, genie_v2_matrix_breakdown_constrained_trio_cov = tup[2], tup[3]
    #asimov_constrained_trio, asimov_constrained_trio_cov = tup[4], tup[5]
    #genie_v2_cov_mat_true_trios, genie_v2_cov_mat_trios, genie_v2_cov_mat_trio_covs = tup[6], tup[7], tup[8]
    #genie_v2_xs_cov_mat_true_trios, genie_v2_xs_cov_mat_trios, genie_v2_xs_cov_mat_trio_covs = tup[9], tup[10], tup[11]
    #genie_v2_genie_true_trios, genie_v2_genie_trios, genie_v2_genie_trio_covs = tup[12], tup[13], tup[14]

# %%
prior_pair = [prior_trio[-3], prior_trio[-1]]
prior_pair_cov = np.array([[prior_cov[-3,-3], prior_cov[-3,-1]], [prior_cov[-1,-3], prior_cov[-1,-1]]])

nuwro_pair = [nuwro_constrained_trio[-3], nuwro_constrained_trio[-1]]
nuwro_pair_cov = np.array([[nuwro_constrained_trio_cov[-3,-3], nuwro_constrained_trio_cov[-3,-1]], [nuwro_constrained_trio_cov[-1,-3], nuwro_constrained_trio_cov[-1,-1]]])
nuwro_plus100_pair = [nuwro_plus100_constrained_trio[-3], nuwro_plus100_constrained_trio[-1]]
nuwro_plus100_pair_cov = np.array([[nuwro_plus100_constrained_trio_cov[-3,-3], nuwro_plus100_constrained_trio_cov[-3,-1]], [nuwro_plus100_constrained_trio_cov[-1,-3], nuwro_plus100_constrained_trio_cov[-1,-1]]])
nuwro_matrix_breakdown_pair = [nuwro_matrix_breakdown_constrained_trio[-3], nuwro_matrix_breakdown_constrained_trio[-1]]
nuwro_matrix_breakdown_pair_cov = np.array([[nuwro_matrix_breakdown_constrained_trio_cov[-3,-3], nuwro_matrix_breakdown_constrained_trio_cov[-3,-1]], [nuwro_matrix_breakdown_constrained_trio_cov[-1,-3], nuwro_matrix_breakdown_constrained_trio_cov[-1,-1]]])

genie_v2_pair = [genie_v2_constrained_trio[-3], genie_v2_constrained_trio[-1]]
genie_v2_pair_cov = np.array([[genie_v2_constrained_trio_cov[-3,-3], genie_v2_constrained_trio_cov[-3,-1]], [genie_v2_constrained_trio_cov[-1,-3], genie_v2_constrained_trio_cov[-1,-1]]])
genie_v2_plus100_pair = [genie_v2_plus100_constrained_trio[-3], genie_v2_plus100_constrained_trio[-1]]
genie_v2_plus100_pair_cov = np.array([[genie_v2_plus100_constrained_trio_cov[-3,-3], genie_v2_plus100_constrained_trio_cov[-3,-1]], [genie_v2_plus100_constrained_trio_cov[-1,-3], genie_v2_plus100_constrained_trio_cov[-1,-1]]])
genie_v2_matrix_breakdown_pair = [genie_v2_matrix_breakdown_constrained_trio[-3], genie_v2_matrix_breakdown_constrained_trio[-1]]
genie_v2_matrix_breakdown_pair_cov = np.array([[genie_v2_matrix_breakdown_constrained_trio_cov[-3,-3], genie_v2_matrix_breakdown_constrained_trio_cov[-3,-1]], [genie_v2_matrix_breakdown_constrained_trio_cov[-1,-3], genie_v2_matrix_breakdown_constrained_trio_cov[-1,-1]]])

# %%
plt.rcParams.update({'font.size': 14})
plt.rcParams['lines.linewidth'] = 3

plt.figure(figsize=(10,7))

plt.scatter([1], [1.1], marker="*", s=200, label=f"Prior best-fit, (1, 1.1)", edgecolors="k", c="tab:blue", zorder=10)
x, y = get_ellipse_x_y_points_from_pair_cov(prior_pair, prior_pair_cov, sigma=2)
plt.plot(x, y, label="Prior 2$\sigma$ Ellipse", c="tab:blue")

plt.scatter([nuwro_pair[1]], [nuwro_pair[0]], marker="*", s=200,
            label=f"Shape+rate posterior best-fit, ({nuwro_pair[1]:.3f}, {nuwro_pair[0]:.3f})"
            , edgecolors="k", c="tab:orange", zorder=10)
x, y = get_ellipse_x_y_points_from_pair_cov(nuwro_pair, nuwro_pair_cov, sigma=2)
plt.plot(x, y, label="Shape+rate 2$\sigma$ Ellipse", c="tab:orange")

plt.scatter([nuwro_plus100_pair[1]], [nuwro_plus100_pair[0]], marker="*", s=200,
            label=f"Shape-Only (+100%) posterior best-fit, ({nuwro_plus100_pair[1]:.3f}, {nuwro_plus100_pair[0]:.3f})"
            , edgecolors="k", c="tab:red", zorder=10)
x, y = get_ellipse_x_y_points_from_pair_cov(nuwro_plus100_pair, nuwro_plus100_pair_cov, sigma=2)
plt.plot(x, y, label="Shape-Only (+100%) 2$\sigma$ Ellipse", c="tab:red")

plt.scatter([nuwro_matrix_breakdown_pair[1]], [nuwro_matrix_breakdown_pair[0]], marker="*", s=200,
            label=f"Shape-Only (Matrix Breakdown) posterior best-fit, ({nuwro_matrix_breakdown_pair[1]:.3f}, {nuwro_matrix_breakdown_pair[0]:.3f})"
            , edgecolors="k", c="tab:green", zorder=10)
x, y = get_ellipse_x_y_points_from_pair_cov(nuwro_matrix_breakdown_pair, nuwro_matrix_breakdown_pair_cov, sigma=2)
plt.plot(x, y, label="Shape-Only (Matrix Breakdown) 2$\sigma$ Ellipse", c="tab:green")

plt.xlabel(r"$\lambda$""\n(total events / CV events)\n(proportional to total cross-section)")
plt.ylabel(r"$M_A$ (GeV/c$^2$)")

plt.legend()

plt.ylim((0.4, 2.5))

plt.title("NuWro Fake Data")

filename = "plots/M_A_vs_lambda_nuwro"
plt.savefig(filename + ".png", dpi=400, facecolor="white")
plt.savefig(filename + ".jpg", dpi=400, facecolor="white")
plt.savefig(filename + ".svg", facecolor="white")



plt.figure(figsize=(10,7))

plt.scatter([1], [1.1], marker="*", s=200, label=f"Prior best-fit, (1, 1.1)", edgecolors="k", c="tab:blue", zorder=10)
x, y = get_ellipse_x_y_points_from_pair_cov(prior_pair, prior_pair_cov, sigma=2)
plt.plot(x, y, label="Prior 2$\sigma$ Ellipse", c="tab:blue")

plt.scatter([genie_v2_pair[1]], [genie_v2_pair[0]], marker="*", s=200,
            label=f"Shape+rate posterior best-fit, ({genie_v2_pair[1]:.3f}, {genie_v2_pair[0]:.3f})"
            , edgecolors="k", c="tab:orange", zorder=10)
x, y = get_ellipse_x_y_points_from_pair_cov(genie_v2_pair, genie_v2_pair_cov, sigma=2)
plt.plot(x, y, label="Shape+rate 2$\sigma$ Ellipse", c="tab:orange")

plt.scatter([genie_v2_plus100_pair[1]], [genie_v2_plus100_pair[0]], marker="*", s=200,
            label=f"Shape-Only (+100%) posterior best-fit, ({genie_v2_plus100_pair[1]:.3f}, {genie_v2_plus100_pair[0]:.3f})"
            , edgecolors="k", c="tab:red", zorder=10)
x, y = get_ellipse_x_y_points_from_pair_cov(genie_v2_plus100_pair, genie_v2_plus100_pair_cov, sigma=2)
plt.plot(x, y, label="Shape-Only (+100%) 2$\sigma$ Ellipse", c="tab:red")

plt.scatter([genie_v2_matrix_breakdown_pair[1]], [genie_v2_matrix_breakdown_pair[0]], marker="*", s=200,
            label=f"Shape-Only (Matrix Breakdown) posterior best-fit, ({genie_v2_matrix_breakdown_pair[1]:.3f}, {genie_v2_matrix_breakdown_pair[0]:.3f})"
            , edgecolors="k", c="tab:green", zorder=10)
x, y = get_ellipse_x_y_points_from_pair_cov(genie_v2_matrix_breakdown_pair, genie_v2_matrix_breakdown_pair_cov, sigma=2)
plt.plot(x, y, label="Shape-Only (Matrix Breakdown) 2$\sigma$ Ellipse", c="tab:green")

plt.xlabel(r"$\lambda$""\n(total events / CV events)\n(proportional to total cross-section)")
plt.ylabel(r"$M_A$ (GeV/c$^2$)")

plt.legend()

plt.ylim((0.4, 2.5))

plt.title("GENIE v2 Fake Data")
filename = "plots/M_A_vs_lambda_genie"
plt.savefig(filename + ".png", dpi=400, facecolor="white")
plt.savefig(filename + ".jpg", dpi=400, facecolor="white")
plt.savefig(filename + ".svg", facecolor="white")

# %% [markdown]
# # Collapsing to 2D and 1D

# %%
with open('trio_pickles/nuwro_fake_rate+shape_2d.pkl', 'rb') as handle:
    tup = pickle.load(handle)
    prior_trio_2d, prior_cov_2d = tup[0], tup[1]
    nuwro_constrained_trio_2d, nuwro_constrained_trio_cov_2d = tup[2], tup[3]
    nuwro_asimov_constrained_trio_2d, nuwro_asimov_constrained_trio_cov_2d = tup[4], tup[5]
    nuwro_cov_mat_true_trios_2d, nuwro_cov_mat_trios_2d, nuwro_cov_mat_trio_covs_2d = tup[6], tup[7], tup[8]
    nuwro_xs_cov_mat_true_trios_2d, nuwro_xs_cov_mat_trios_2d, nuwro_xs_cov_mat_trio_covs_2d = tup[9], tup[10], tup[11]
    nuwro_genie_true_trios_2d, nuwro_genie_trios_2d, nuwro_genie_trio_covs_2d = tup[12], tup[13], tup[14]

nuwro_reco_MA_2d = nuwro_constrained_trio_2d[0]
nuwro_reco_MA_sigma_2d = np.sqrt(nuwro_constrained_trio_cov_2d[0,0])
x = nuwro_reco_MA_2d
dx = nuwro_reco_MA_sigma_2d
nuwro_reco_MA_prior_removed_2d = (dp * dp * x - dx * dx * p) / (dp * dp - dx * dx)
nuwro_reco_MA_sigma_prior_removed_2d = (dp * dx) / np.sqrt(dp * dp - dx * dx)

asimov_true_MA_2d = prior_trio_2d[0]
asimov_reco_MA_2d = nuwro_asimov_constrained_trio_2d[0]
asimov_reco_MA_sigma_2d = np.sqrt(nuwro_asimov_constrained_trio_cov_2d[0,0])
x = asimov_reco_MA_2d
dx = asimov_reco_MA_sigma_2d
asimov_reco_MA_prior_removed_2d = (dp * dp * x - dx * dx * p) / (dp * dp - dx * dx)
asimov_reco_MA_sigma_prior_removed_2d = (dp * dx) / np.sqrt(dp * dp - dx * dx)

nuwro_cov_mat_true_MAs_2d = np.array([x[0] for x in nuwro_cov_mat_true_trios_2d])
nuwro_cov_mat_reco_MAs_2d = np.array([x[0] for x in nuwro_cov_mat_trios_2d])
nuwro_cov_mat_reco_MA_sigmas_2d = [np.sqrt(x[0,0]) for x in nuwro_cov_mat_trio_covs_2d]
x = nuwro_cov_mat_reco_MAs_2d
dx = nuwro_cov_mat_reco_MA_sigmas_2d
nuwro_cov_mat_reco_MAs_prior_removed_2d = [(dp * dp * x[i] - dx[i] * dx[i] * p) / (dp * dp - dx[i] * dx[i]) for i in range(len(x))]
nuwro_cov_mat_reco_MA_sigmas_prior_removed_2d = [(dp * dx[i]) / np.sqrt(dp * dp - dx[i] * dx[i]) for i in range(len(x))]

nuwro_xs_cov_mat_true_MAs_2d = np.array([x[0] for x in nuwro_xs_cov_mat_true_trios_2d])
nuwro_xs_cov_mat_reco_MAs_2d = np.array([x[0] for x in nuwro_xs_cov_mat_trios_2d])
nuwro_xs_cov_mat_reco_MA_sigmas_2d = np.array([np.sqrt(x[0,0]) for x in nuwro_xs_cov_mat_trio_covs_2d])
x = nuwro_xs_cov_mat_reco_MAs_2d
dx = nuwro_xs_cov_mat_reco_MA_sigmas_2d
nuwro_xs_cov_mat_reco_MAs_prior_removed_2d = np.array([(dp * dp * x[i] - dx[i] * dx[i] * p) / (dp * dp - dx[i] * dx[i]) for i in range(len(x))])
nuwro_xs_cov_mat_reco_MA_sigmas_prior_removed_2d = np.array([(dp * dx[i]) / np.sqrt(dp * dp - dx[i] * dx[i]) for i in range(len(x))])

nuwro_genie_true_MAs_2d = np.array([x[0] for x in nuwro_genie_true_trios_2d])
nuwro_genie_reco_MAs_2d = np.array([x[0] for x in nuwro_genie_trios_2d])
nuwro_genie_reco_MA_sigmas_2d = np.array([np.sqrt(x[0,0]) for x in nuwro_genie_trio_covs_2d])
x = nuwro_genie_reco_MAs_2d
dx = nuwro_genie_reco_MA_sigmas_2d
nuwro_genie_reco_MAs_prior_removed_2d = np.array([(dp * dp * x[i] - dx[i] * dx[i] * p) / (dp * dp - dx[i] * dx[i]) for i in range(len(x))])
nuwro_genie_reco_MA_sigmas_prior_removed_2d = np.array([(dp * dx[i]) / np.sqrt(dp * dp - dx[i] * dx[i]) for i in range(len(x))])



with open('trio_pickles/nuwro_fake_rate+shape_1d.pkl', 'rb') as handle:
    tup = pickle.load(handle)
    prior_trio_1d, prior_cov_1d = tup[0], tup[1]
    nuwro_constrained_trio_1d, nuwro_constrained_trio_cov_1d = tup[2], tup[3]
    nuwro_asimov_constrained_trio_1d, nuwro_asimov_constrained_trio_cov_1d = tup[4], tup[5]
    nuwro_cov_mat_true_trios_1d, nuwro_cov_mat_trios_1d, nuwro_cov_mat_trio_covs_1d = tup[6], tup[7], tup[8]
    nuwro_xs_cov_mat_true_trios_1d, nuwro_xs_cov_mat_trios_1d, nuwro_xs_cov_mat_trio_covs_1d = tup[9], tup[10], tup[11]
    nuwro_genie_true_trios_1d, nuwro_genie_trios_1d, nuwro_genie_trio_covs_1d = tup[12], tup[13], tup[14]

nuwro_reco_MA_1d = nuwro_constrained_trio_1d[0]
nuwro_reco_MA_sigma_1d = np.sqrt(nuwro_constrained_trio_cov_1d[0,0])
x = nuwro_reco_MA_1d
dx = nuwro_reco_MA_sigma_1d
nuwro_reco_MA_prior_removed_1d = (dp * dp * x - dx * dx * p) / (dp * dp - dx * dx)
nuwro_reco_MA_sigma_prior_removed_1d = (dp * dx) / np.sqrt(dp * dp - dx * dx)

asimov_true_MA_1d = prior_trio_1d[0]
asimov_reco_MA_1d = nuwro_asimov_constrained_trio_1d[0]
asimov_reco_MA_sigma_1d = np.sqrt(nuwro_asimov_constrained_trio_cov_1d[0,0])
x = asimov_reco_MA_1d
dx = asimov_reco_MA_sigma_1d
asimov_reco_MA_prior_removed_1d = (dp * dp * x - dx * dx * p) / (dp * dp - dx * dx)
asimov_reco_MA_sigma_prior_removed_1d = (dp * dx) / np.sqrt(dp * dp - dx * dx)

nuwro_cov_mat_true_MAs_1d = np.array([x[0] for x in nuwro_cov_mat_true_trios_1d])
nuwro_cov_mat_reco_MAs_1d = np.array([x[0] for x in nuwro_cov_mat_trios_1d])
nuwro_cov_mat_reco_MA_sigmas_1d = [np.sqrt(x[0,0]) for x in nuwro_cov_mat_trio_covs_1d]
x = nuwro_cov_mat_reco_MAs_1d
dx = nuwro_cov_mat_reco_MA_sigmas_1d
nuwro_cov_mat_reco_MAs_prior_removed_1d = [(dp * dp * x[i] - dx[i] * dx[i] * p) / (dp * dp - dx[i] * dx[i]) for i in range(len(x))]
nuwro_cov_mat_reco_MA_sigmas_prior_removed_1d = [(dp * dx[i]) / np.sqrt(dp * dp - dx[i] * dx[i]) for i in range(len(x))]

nuwro_xs_cov_mat_true_MAs_1d = np.array([x[0] for x in nuwro_xs_cov_mat_true_trios_1d])
nuwro_xs_cov_mat_reco_MAs_1d = np.array([x[0] for x in nuwro_xs_cov_mat_trios_1d])
nuwro_xs_cov_mat_reco_MA_sigmas_1d = np.array([np.sqrt(x[0,0]) for x in nuwro_xs_cov_mat_trio_covs_1d])
x = nuwro_xs_cov_mat_reco_MAs_1d
dx = nuwro_xs_cov_mat_reco_MA_sigmas_1d
nuwro_xs_cov_mat_reco_MAs_prior_removed_1d = np.array([(dp * dp * x[i] - dx[i] * dx[i] * p) / (dp * dp - dx[i] * dx[i]) for i in range(len(x))])
nuwro_xs_cov_mat_reco_MA_sigmas_prior_removed_1d = np.array([(dp * dx[i]) / np.sqrt(dp * dp - dx[i] * dx[i]) for i in range(len(x))])

nuwro_genie_true_MAs_1d = np.array([x[0] for x in nuwro_genie_true_trios_1d])
nuwro_genie_reco_MAs_1d = np.array([x[0] for x in nuwro_genie_trios_1d])
nuwro_genie_reco_MA_sigmas_1d = np.array([np.sqrt(x[0,0]) for x in nuwro_genie_trio_covs_1d])
x = nuwro_genie_reco_MAs_1d
dx = nuwro_genie_reco_MA_sigmas_1d
nuwro_genie_reco_MAs_prior_removed_1d = np.array([(dp * dp * x[i] - dx[i] * dx[i] * p) / (dp * dp - dx[i] * dx[i]) for i in range(len(x))])
nuwro_genie_reco_MA_sigmas_prior_removed_1d = np.array([(dp * dx[i]) / np.sqrt(dp * dp - dx[i] * dx[i]) for i in range(len(x))])

# %%
with open('trio_pickles/genie_v2_fake_rate+shape_2d.pkl', 'rb') as handle:
    tup = pickle.load(handle)
    prior_trio_2d, prior_cov_2d = tup[0], tup[1]
    genie_v2_constrained_trio_2d, genie_v2_constrained_trio_cov_2d = tup[2], tup[3]
    genie_v2_asimov_constrained_trio_2d, genie_v2_asimov_constrained_trio_cov_2d = tup[4], tup[5]
    genie_v2_cov_mat_true_trios_2d, genie_v2_cov_mat_trios_2d, genie_v2_cov_mat_trio_covs_2d = tup[6], tup[7], tup[8]
    genie_v2_xs_cov_mat_true_trios_2d, genie_v2_xs_cov_mat_trios_2d, genie_v2_xs_cov_mat_trio_covs_2d = tup[9], tup[10], tup[11]
    genie_v2_genie_true_trios_2d, genie_v2_genie_trios_2d, genie_v2_genie_trio_covs_2d = tup[12], tup[13], tup[14]

genie_v2_reco_MA_2d = genie_v2_constrained_trio_2d[0]
genie_v2_reco_MA_sigma_2d = np.sqrt(genie_v2_constrained_trio_cov_2d[0,0])
x = genie_v2_reco_MA_2d
dx = genie_v2_reco_MA_sigma_2d
genie_v2_reco_MA_prior_removed_2d = (dp * dp * x - dx * dx * p) / (dp * dp - dx * dx)
genie_v2_reco_MA_sigma_prior_removed_2d = (dp * dx) / np.sqrt(dp * dp - dx * dx)

asimov_true_MA_2d = prior_trio_2d[0]
asimov_reco_MA_2d = genie_v2_asimov_constrained_trio_2d[0]
asimov_reco_MA_sigma_2d = np.sqrt(genie_v2_asimov_constrained_trio_cov_2d[0,0])
x = asimov_reco_MA_2d
dx = asimov_reco_MA_sigma_2d
asimov_reco_MA_prior_removed_2d = (dp * dp * x - dx * dx * p) / (dp * dp - dx * dx)
asimov_reco_MA_sigma_prior_removed_2d = (dp * dx) / np.sqrt(dp * dp - dx * dx)

genie_v2_cov_mat_true_MAs_2d = np.array([x[0] for x in genie_v2_cov_mat_true_trios_2d])
genie_v2_cov_mat_reco_MAs_2d = np.array([x[0] for x in genie_v2_cov_mat_trios_2d])
genie_v2_cov_mat_reco_MA_sigmas_2d = [np.sqrt(x[0,0]) for x in genie_v2_cov_mat_trio_covs_2d]
x = genie_v2_cov_mat_reco_MAs_2d
dx = genie_v2_cov_mat_reco_MA_sigmas_2d
genie_v2_cov_mat_reco_MAs_prior_removed_2d = [(dp * dp * x[i] - dx[i] * dx[i] * p) / (dp * dp - dx[i] * dx[i]) for i in range(len(x))]
genie_v2_cov_mat_reco_MA_sigmas_prior_removed_2d = [(dp * dx[i]) / np.sqrt(dp * dp - dx[i] * dx[i]) for i in range(len(x))]

genie_v2_xs_cov_mat_true_MAs_2d = np.array([x[0] for x in genie_v2_xs_cov_mat_true_trios_2d])
genie_v2_xs_cov_mat_reco_MAs_2d = np.array([x[0] for x in genie_v2_xs_cov_mat_trios_2d])
genie_v2_xs_cov_mat_reco_MA_sigmas_2d = np.array([np.sqrt(x[0,0]) for x in genie_v2_xs_cov_mat_trio_covs_2d])
x = genie_v2_xs_cov_mat_reco_MAs_2d
dx = genie_v2_xs_cov_mat_reco_MA_sigmas_2d
genie_v2_xs_cov_mat_reco_MAs_prior_removed_2d = np.array([(dp * dp * x[i] - dx[i] * dx[i] * p) / (dp * dp - dx[i] * dx[i]) for i in range(len(x))])
genie_v2_xs_cov_mat_reco_MA_sigmas_prior_removed_2d = np.array([(dp * dx[i]) / np.sqrt(dp * dp - dx[i] * dx[i]) for i in range(len(x))])

genie_v2_genie_true_MAs_2d = np.array([x[0] for x in genie_v2_genie_true_trios_2d])
genie_v2_genie_reco_MAs_2d = np.array([x[0] for x in genie_v2_genie_trios_2d])
genie_v2_genie_reco_MA_sigmas_2d = np.array([np.sqrt(x[0,0]) for x in genie_v2_genie_trio_covs_2d])
x = genie_v2_genie_reco_MAs_2d
dx = genie_v2_genie_reco_MA_sigmas_2d
genie_v2_genie_reco_MAs_prior_removed_2d = np.array([(dp * dp * x[i] - dx[i] * dx[i] * p) / (dp * dp - dx[i] * dx[i]) for i in range(len(x))])
genie_v2_genie_reco_MA_sigmas_prior_removed_2d = np.array([(dp * dx[i]) / np.sqrt(dp * dp - dx[i] * dx[i]) for i in range(len(x))])



with open('trio_pickles/genie_v2_fake_rate+shape_1d.pkl', 'rb') as handle:
    tup = pickle.load(handle)
    prior_trio_1d, prior_cov_1d = tup[0], tup[1]
    genie_v2_constrained_trio_1d, genie_v2_constrained_trio_cov_1d = tup[2], tup[3]
    genie_v2_asimov_constrained_trio_1d, genie_v2_asimov_constrained_trio_cov_1d = tup[4], tup[5]
    genie_v2_cov_mat_true_trios_1d, genie_v2_cov_mat_trios_1d, genie_v2_cov_mat_trio_covs_1d = tup[6], tup[7], tup[8]
    genie_v2_xs_cov_mat_true_trios_1d, genie_v2_xs_cov_mat_trios_1d, genie_v2_xs_cov_mat_trio_covs_1d = tup[9], tup[10], tup[11]
    genie_v2_genie_true_trios_1d, genie_v2_genie_trios_1d, genie_v2_genie_trio_covs_1d = tup[12], tup[13], tup[14]

genie_v2_reco_MA_1d = genie_v2_constrained_trio_1d[0]
genie_v2_reco_MA_sigma_1d = np.sqrt(genie_v2_constrained_trio_cov_1d[0,0])
x = genie_v2_reco_MA_1d
dx = genie_v2_reco_MA_sigma_1d
genie_v2_reco_MA_prior_removed_1d = (dp * dp * x - dx * dx * p) / (dp * dp - dx * dx)
genie_v2_reco_MA_sigma_prior_removed_1d = (dp * dx) / np.sqrt(dp * dp - dx * dx)

asimov_true_MA_1d = prior_trio_1d[0]
asimov_reco_MA_1d = genie_v2_asimov_constrained_trio_1d[0]
asimov_reco_MA_sigma_1d = np.sqrt(genie_v2_asimov_constrained_trio_cov_1d[0,0])
x = asimov_reco_MA_1d
dx = asimov_reco_MA_sigma_1d
asimov_reco_MA_prior_removed_1d = (dp * dp * x - dx * dx * p) / (dp * dp - dx * dx)
asimov_reco_MA_sigma_prior_removed_1d = (dp * dx) / np.sqrt(dp * dp - dx * dx)

genie_v2_cov_mat_true_MAs_1d = np.array([x[0] for x in genie_v2_cov_mat_true_trios_1d])
genie_v2_cov_mat_reco_MAs_1d = np.array([x[0] for x in genie_v2_cov_mat_trios_1d])
genie_v2_cov_mat_reco_MA_sigmas_1d = [np.sqrt(x[0,0]) for x in genie_v2_cov_mat_trio_covs_1d]
x = genie_v2_cov_mat_reco_MAs_1d
dx = genie_v2_cov_mat_reco_MA_sigmas_1d
genie_v2_cov_mat_reco_MAs_prior_removed_1d = [(dp * dp * x[i] - dx[i] * dx[i] * p) / (dp * dp - dx[i] * dx[i]) for i in range(len(x))]
genie_v2_cov_mat_reco_MA_sigmas_prior_removed_1d = [(dp * dx[i]) / np.sqrt(dp * dp - dx[i] * dx[i]) for i in range(len(x))]

genie_v2_xs_cov_mat_true_MAs_1d = np.array([x[0] for x in genie_v2_xs_cov_mat_true_trios_1d])
genie_v2_xs_cov_mat_reco_MAs_1d = np.array([x[0] for x in genie_v2_xs_cov_mat_trios_1d])
genie_v2_xs_cov_mat_reco_MA_sigmas_1d = np.array([np.sqrt(x[0,0]) for x in genie_v2_xs_cov_mat_trio_covs_1d])
x = genie_v2_xs_cov_mat_reco_MAs_1d
dx = genie_v2_xs_cov_mat_reco_MA_sigmas_1d
genie_v2_xs_cov_mat_reco_MAs_prior_removed_1d = np.array([(dp * dp * x[i] - dx[i] * dx[i] * p) / (dp * dp - dx[i] * dx[i]) for i in range(len(x))])
genie_v2_xs_cov_mat_reco_MA_sigmas_prior_removed_1d = np.array([(dp * dx[i]) / np.sqrt(dp * dp - dx[i] * dx[i]) for i in range(len(x))])

genie_v2_genie_true_MAs_1d = np.array([x[0] for x in genie_v2_genie_true_trios_1d])
genie_v2_genie_reco_MAs_1d = np.array([x[0] for x in genie_v2_genie_trios_1d])
genie_v2_genie_reco_MA_sigmas_1d = np.array([np.sqrt(x[0,0]) for x in genie_v2_genie_trio_covs_1d])
x = genie_v2_genie_reco_MAs_1d
dx = genie_v2_genie_reco_MA_sigmas_1d
genie_v2_genie_reco_MAs_prior_removed_1d = np.array([(dp * dp * x[i] - dx[i] * dx[i] * p) / (dp * dp - dx[i] * dx[i]) for i in range(len(x))])
genie_v2_genie_reco_MA_sigmas_prior_removed_1d = np.array([(dp * dx[i]) / np.sqrt(dp * dp - dx[i] * dx[i]) for i in range(len(x))])

# %%
plt.rcParams.update({'font.size': 7})


plt.figure(figsize=(10,7))
plt.plot([0.7, 1.5], [0.7, 1.5], c="k", ls="dashed", lw=2, zorder=5)
plt.fill_between([0.7, 1.5], [prior_MA - prior_MA_sigma, prior_MA - prior_MA_sigma], [prior_MA + prior_MA_sigma, prior_MA + prior_MA_sigma], color="gray", alpha=0.2, label="GENIE Prior")

plt.scatter(nuwro_cov_mat_true_MAs_2d, nuwro_cov_mat_reco_MAs_2d, s=s, c="tab:blue", label="600 fake data sets\nfrom covariance matrix variations", zorder=0)
plt.errorbar(nuwro_cov_mat_true_MAs_2d, nuwro_cov_mat_reco_MAs_2d, yerr=nuwro_cov_mat_reco_MA_sigmas_2d, c="tab:blue", fmt="none", capsize=4, lw=1, capthick=1, zorder=0)

plt.scatter(nuwro_xs_cov_mat_true_MAs_2d, nuwro_xs_cov_mat_reco_MAs_2d, s=s, c="tab:orange", label="600 fake data sets\nfrom CV with XS covariance matrix variations", zorder=1)
plt.errorbar(nuwro_xs_cov_mat_true_MAs_2d, nuwro_xs_cov_mat_reco_MAs_2d, yerr=nuwro_xs_cov_mat_reco_MA_sigmas_2d, c="tab:orange", fmt="none", capsize=4, lw=1, capthick=1, zorder=1)

plt.scatter(nuwro_genie_true_MAs_2d, nuwro_genie_reco_MAs_2d, s=s, c="tab:green", label="600 fake data sets\nfrom CV with GENIE universe variations", zorder=1)
plt.errorbar(nuwro_genie_true_MAs_2d, nuwro_genie_reco_MAs_2d, yerr=nuwro_genie_reco_MA_sigmas_2d, c="tab:green", fmt="none", capsize=4, lw=1, capthick=1, zorder=1)

plt.scatter(asimov_true_MA, asimov_reco_MA_2d, s=30, label=f"Asimov fake data: {asimov_reco_MA_2d:.3f} "r"$\pm$"f" {asimov_reco_MA_sigma_2d:.3f} "
            r"$\mathrm{GeV/c^2}$"f"\n\t\t\tTrue: {asimov_true_MA_2d:.3f} "r"$\mathrm{GeV/c^2}$""\n\t\t\t"
            fr"$\sigma = {np.abs(asimov_true_MA_2d - asimov_reco_MA_2d)/asimov_reco_MA_sigma_2d:.3f}$", c="tab:red", zorder=10)
plt.scatter(asimov_true_MA, asimov_reco_MA_2d, s=70, c="k", zorder=9)
plt.errorbar(asimov_true_MA, asimov_reco_MA_2d, yerr=asimov_reco_MA_sigma_2d, fmt="none", c="tab:red", capthick=2, elinewidth=2, capsize=5, zorder=10)
plt.errorbar(asimov_true_MA, asimov_reco_MA_2d, yerr=asimov_reco_MA_sigma_2d, fmt="none", c="k", capthick=4, elinewidth=4, capsize=6, zorder=9)

plt.scatter(nuwro_fake_data_true_MA, nuwro_reco_MA_2d, s=30, label=f"NuWro fake data: {nuwro_reco_MA_2d:.3f} "r"$\pm$"f" {nuwro_reco_MA_sigma_2d:.3f} "
            r"$\mathrm{GeV/c^2}$"f"\n\t\t\tTrue: {nuwro_fake_data_true_MA:.3f} "r"$\mathrm{GeV/c^2}$""\n\t\t\t"
            fr"$\sigma = {np.abs(nuwro_fake_data_true_MA - nuwro_reco_MA_2d)/nuwro_reco_MA_sigma_2d:.3f}$", c="tab:brown", zorder=10)
plt.scatter(nuwro_fake_data_true_MA, nuwro_reco_MA_2d, s=70, c="k", zorder=9)
plt.errorbar(nuwro_fake_data_true_MA, nuwro_reco_MA_2d, yerr=nuwro_reco_MA_sigma_2d, fmt="none", c="tab:brown", capthick=2, elinewidth=2, capsize=5, zorder=10)
plt.errorbar(nuwro_fake_data_true_MA, nuwro_reco_MA_2d, yerr=nuwro_reco_MA_sigma_2d, fmt="none", c="k", capthick=4, elinewidth=4, capsize=6, zorder=9)

plt.scatter(genie_v2_fake_data_true_MA, genie_v2_reco_MA_2d, s=30, label=f"GENIE v2 fake data: {genie_v2_reco_MA_2d:.3f} "r"$\pm$"f" {genie_v2_reco_MA_sigma_2d:.3f} "
            r"$\mathrm{GeV/c^2}$"f"\n\t\t\tTrue: {genie_v2_fake_data_true_MA:.3f} "r"$\mathrm{GeV/c^2}$""\n\t\t\t"
            fr"$\sigma = {np.abs(genie_v2_fake_data_true_MA - genie_v2_reco_MA_2d)/genie_v2_reco_MA_sigma_2d:.3f}$", c="tab:purple", zorder=10)
plt.scatter(genie_v2_fake_data_true_MA, genie_v2_reco_MA_2d, s=70, c="k", zorder=9)
plt.errorbar(genie_v2_fake_data_true_MA, genie_v2_reco_MA_2d, yerr=genie_v2_reco_MA_sigma_2d, fmt="none", c="tab:purple", capthick=2, elinewidth=2, capsize=5, zorder=10)
plt.errorbar(genie_v2_fake_data_true_MA, genie_v2_reco_MA_2d, yerr=genie_v2_reco_MA_sigma_2d, fmt="none", c="k", capthick=4, elinewidth=4, capsize=6, zorder=9)

plt.legend(loc="upper left")
plt.xlabel(r"True $M_A$ (GeV/c$^2$)")
plt.ylabel(r"Reco $M_A$ Posterior (GeV/c$^2$)")
plt.xlim(0.7, 1.5)
plt.ylim(0.7, 1.5)
plt.title(r"Collapsed to 2d ($P_\mu$, $\cos \theta_\mu$)")
filename = "plots/2d"
plt.savefig(filename + ".png", facecolor="white", dpi=300)
plt.savefig(filename + ".jpg", facecolor="white", dpi=300)
plt.savefig(filename + ".svg", facecolor="white")

plt.figure(figsize=(10,7))
plt.plot([0.7, 1.5], [0.7, 1.5], c="k", ls="dashed", lw=2, zorder=5)

plt.scatter(nuwro_cov_mat_true_MAs_2d, nuwro_cov_mat_reco_MAs_prior_removed_2d, s=s, c="tab:blue", label="600 fake data sets\nfrom covariance matrix variations", zorder=0)
plt.errorbar(nuwro_cov_mat_true_MAs_2d, nuwro_cov_mat_reco_MAs_prior_removed_2d, yerr=nuwro_cov_mat_reco_MA_sigmas_prior_removed_2d, c="tab:blue", fmt="none", capsize=4, lw=1, capthick=1, zorder=0)

plt.scatter(nuwro_xs_cov_mat_true_MAs_2d, nuwro_xs_cov_mat_reco_MAs_prior_removed_2d, s=s, c="tab:orange", label="600 fake data sets\nfrom CV with XS covariance matrix variations", zorder=1)
plt.errorbar(nuwro_xs_cov_mat_true_MAs_2d, nuwro_xs_cov_mat_reco_MAs_prior_removed_2d, yerr=nuwro_xs_cov_mat_reco_MA_sigmas_prior_removed_2d, c="tab:orange", fmt="none", capsize=4, lw=1, capthick=1, zorder=1)

plt.scatter(nuwro_genie_true_MAs_2d, nuwro_genie_reco_MAs_prior_removed_2d, s=s, c="tab:green", label="600 fake data sets\nfrom CV with GENIE universe variations", zorder=1)
plt.errorbar(nuwro_genie_true_MAs_2d, nuwro_genie_reco_MAs_prior_removed_2d, yerr=nuwro_genie_reco_MA_sigmas_prior_removed_2d, c="tab:green", fmt="none", capsize=4, lw=1, capthick=1, zorder=1)

plt.scatter(asimov_true_MA, asimov_reco_MA_prior_removed_2d, s=30, label=f"Asimov fake data: {asimov_reco_MA_prior_removed_2d:.3f} "r"$\pm$"f" {asimov_reco_MA_sigma_prior_removed_2d:.3f} "
            r"$\mathrm{GeV/c^2}$"f"\n\t\t\tTrue: {asimov_true_MA_2d:.3f} "r"$\mathrm{GeV/c^2}$""\n\t\t\t"
            fr"$\sigma = {np.abs(asimov_true_MA_2d - asimov_reco_MA_prior_removed_2d)/asimov_reco_MA_sigma_prior_removed_2d:.3f}$", c="tab:red", zorder=10)
plt.scatter(asimov_true_MA, asimov_reco_MA_prior_removed_2d, s=70, c="k", zorder=9)
plt.errorbar(asimov_true_MA, asimov_reco_MA_prior_removed_2d, yerr=asimov_reco_MA_sigma_prior_removed_2d, fmt="none", c="tab:red", capthick=2, elinewidth=2, capsize=5, zorder=10)
plt.errorbar(asimov_true_MA, asimov_reco_MA_prior_removed_2d, yerr=asimov_reco_MA_sigma_prior_removed_2d, fmt="none", c="k", capthick=4, elinewidth=4, capsize=6, zorder=9)

plt.scatter(nuwro_fake_data_true_MA, nuwro_reco_MA_prior_removed_2d, s=30, label=f"NuWro fake data: {nuwro_reco_MA_prior_removed_2d:.3f} "r"$\pm$"f" {nuwro_reco_MA_sigma_prior_removed_2d:.3f} "
            r"$\mathrm{GeV/c^2}$"f"\n\t\t\tTrue: {nuwro_fake_data_true_MA:.3f} "r"$\mathrm{GeV/c^2}$""\n\t\t\t"
            fr"$\sigma = {np.abs(nuwro_fake_data_true_MA - nuwro_reco_MA_prior_removed_2d)/nuwro_reco_MA_sigma_prior_removed_2d:.3f}$", c="tab:brown", zorder=10)
plt.scatter(nuwro_fake_data_true_MA, nuwro_reco_MA_prior_removed_2d, s=70, c="k", zorder=9)
plt.errorbar(nuwro_fake_data_true_MA, nuwro_reco_MA_prior_removed_2d, yerr=nuwro_reco_MA_sigma_prior_removed_2d, fmt="none", c="tab:brown", capthick=2, elinewidth=2, capsize=5, zorder=10)
plt.errorbar(nuwro_fake_data_true_MA, nuwro_reco_MA_prior_removed_2d, yerr=nuwro_reco_MA_sigma_prior_removed_2d, fmt="none", c="k", capthick=4, elinewidth=4, capsize=6, zorder=9)

plt.scatter(genie_v2_fake_data_true_MA, genie_v2_reco_MA_prior_removed_2d, s=30, label=f"GENIE v2 fake data: {genie_v2_reco_MA_prior_removed_2d:.3f} "r"$\pm$"f" {genie_v2_reco_MA_sigma_prior_removed_2d:.3f} "
            r"$\mathrm{GeV/c^2}$"f"\n\t\t\tTrue: {genie_v2_fake_data_true_MA:.3f} "r"$\mathrm{GeV/c^2}$""\n\t\t\t"
            fr"$\sigma = {np.abs(genie_v2_fake_data_true_MA - genie_v2_reco_MA_prior_removed_2d)/genie_v2_reco_MA_sigma_prior_removed_2d:.3f}$", c="tab:purple", zorder=10)
plt.scatter(genie_v2_fake_data_true_MA, genie_v2_reco_MA_prior_removed_2d, s=70, c="k", zorder=9)
plt.errorbar(genie_v2_fake_data_true_MA, genie_v2_reco_MA_prior_removed_2d, yerr=genie_v2_reco_MA_sigma_prior_removed_2d, fmt="none", c="tab:purple", capthick=2, elinewidth=2, capsize=5, zorder=10)
plt.errorbar(genie_v2_fake_data_true_MA, genie_v2_reco_MA_prior_removed_2d, yerr=genie_v2_reco_MA_sigma_prior_removed_2d, fmt="none", c="k", capthick=4, elinewidth=4, capsize=6, zorder=9)

plt.legend(loc="upper left")
plt.xlabel(r"True $M_A$ (GeV/c$^2$)")
plt.ylabel(r"Reco $M_A$ (GeV/c$^2$)")
plt.xlim(0.7, 1.5)
plt.ylim(0.7, 1.5)
plt.title(r"Collapsed to 2d ($P_\mu$, $\cos \theta_\mu$)")
filename = "plots/2d_no_prior"
plt.savefig(filename + ".png", facecolor="white", dpi=300)
plt.savefig(filename + ".jpg", facecolor="white", dpi=300)
plt.savefig(filename + ".svg", facecolor="white")

# %%
plt.rcParams.update({'font.size': 7})


plt.figure(figsize=(10,7))
plt.plot([0.7, 1.5], [0.7, 1.5], c="k", ls="dashed", lw=2, zorder=5)
plt.fill_between([0.7, 1.5], [prior_MA - prior_MA_sigma, prior_MA - prior_MA_sigma], [prior_MA + prior_MA_sigma, prior_MA + prior_MA_sigma], color="gray", alpha=0.2, label="GENIE Prior")

plt.scatter(nuwro_cov_mat_true_MAs_1d, nuwro_cov_mat_reco_MAs_1d, s=s, c="tab:blue", label="600 fake data sets\nfrom covariance matrix variations", zorder=0)
plt.errorbar(nuwro_cov_mat_true_MAs_1d, nuwro_cov_mat_reco_MAs_1d, yerr=nuwro_cov_mat_reco_MA_sigmas_1d, c="tab:blue", fmt="none", capsize=4, lw=1, capthick=1, zorder=0)

plt.scatter(nuwro_xs_cov_mat_true_MAs_1d, nuwro_xs_cov_mat_reco_MAs_1d, s=s, c="tab:orange", label="600 fake data sets\nfrom CV with XS covariance matrix variations", zorder=1)
plt.errorbar(nuwro_xs_cov_mat_true_MAs_1d, nuwro_xs_cov_mat_reco_MAs_1d, yerr=nuwro_xs_cov_mat_reco_MA_sigmas_1d, c="tab:orange", fmt="none", capsize=4, lw=1, capthick=1, zorder=1)

plt.scatter(nuwro_genie_true_MAs_1d, nuwro_genie_reco_MAs_1d, s=s, c="tab:green", label="600 fake data sets\nfrom CV with GENIE universe variations", zorder=1)
plt.errorbar(nuwro_genie_true_MAs_1d, nuwro_genie_reco_MAs_1d, yerr=nuwro_genie_reco_MA_sigmas_1d, c="tab:green", fmt="none", capsize=4, lw=1, capthick=1, zorder=1)

plt.scatter(asimov_true_MA, asimov_reco_MA_1d, s=30, label=f"Asimov fake data: {asimov_reco_MA_1d:.3f} "r"$\pm$"f" {asimov_reco_MA_sigma_1d:.3f} "
            r"$\mathrm{GeV/c^2}$"f"\n\t\t\tTrue: {asimov_true_MA_1d:.3f} "r"$\mathrm{GeV/c^2}$""\n\t\t\t"
            fr"$\sigma = {np.abs(asimov_true_MA_1d - asimov_reco_MA_1d)/asimov_reco_MA_sigma_1d:.3f}$", c="tab:red", zorder=10)
plt.scatter(asimov_true_MA, asimov_reco_MA_1d, s=70, c="k", zorder=9)
plt.errorbar(asimov_true_MA, asimov_reco_MA_1d, yerr=asimov_reco_MA_sigma_1d, fmt="none", c="tab:red", capthick=2, elinewidth=2, capsize=5, zorder=10)
plt.errorbar(asimov_true_MA, asimov_reco_MA_1d, yerr=asimov_reco_MA_sigma_1d, fmt="none", c="k", capthick=4, elinewidth=4, capsize=6, zorder=9)

plt.scatter(nuwro_fake_data_true_MA, nuwro_reco_MA_1d, s=30, label=f"NuWro fake data: {nuwro_reco_MA_1d:.3f} "r"$\pm$"f" {nuwro_reco_MA_sigma_1d:.3f} "
            r"$\mathrm{GeV/c^2}$"f"\n\t\t\tTrue: {nuwro_fake_data_true_MA:.3f} "r"$\mathrm{GeV/c^2}$""\n\t\t\t"
            fr"$\sigma = {np.abs(nuwro_fake_data_true_MA - nuwro_reco_MA_1d)/nuwro_reco_MA_sigma_1d:.3f}$", c="tab:brown", zorder=10)
plt.scatter(nuwro_fake_data_true_MA, nuwro_reco_MA_1d, s=70, c="k", zorder=9)
plt.errorbar(nuwro_fake_data_true_MA, nuwro_reco_MA_1d, yerr=nuwro_reco_MA_sigma_1d, fmt="none", c="tab:brown", capthick=2, elinewidth=2, capsize=5, zorder=10)
plt.errorbar(nuwro_fake_data_true_MA, nuwro_reco_MA_1d, yerr=nuwro_reco_MA_sigma_1d, fmt="none", c="k", capthick=4, elinewidth=4, capsize=6, zorder=9)

plt.scatter(genie_v2_fake_data_true_MA, genie_v2_reco_MA_1d, s=30, label=f"GENIE v2 fake data: {genie_v2_reco_MA_1d:.3f} "r"$\pm$"f" {genie_v2_reco_MA_sigma_1d:.3f} "
            r"$\mathrm{GeV/c^2}$"f"\n\t\t\tTrue: {genie_v2_fake_data_true_MA:.3f} "r"$\mathrm{GeV/c^2}$""\n\t\t\t"
            fr"$\sigma = {np.abs(genie_v2_fake_data_true_MA - genie_v2_reco_MA_1d)/genie_v2_reco_MA_sigma_1d:.3f}$", c="tab:purple", zorder=10)
plt.scatter(genie_v2_fake_data_true_MA, genie_v2_reco_MA_1d, s=70, c="k", zorder=9)
plt.errorbar(genie_v2_fake_data_true_MA, genie_v2_reco_MA_1d, yerr=genie_v2_reco_MA_sigma_1d, fmt="none", c="tab:purple", capthick=2, elinewidth=2, capsize=5, zorder=10)
plt.errorbar(genie_v2_fake_data_true_MA, genie_v2_reco_MA_1d, yerr=genie_v2_reco_MA_sigma_1d, fmt="none", c="k", capthick=4, elinewidth=4, capsize=6, zorder=9)

plt.legend(loc="upper left")
plt.xlabel(r"True $M_A$ (GeV/c$^2$)")
plt.ylabel(r"Reco $M_A$ Posterior (GeV/c$^2$)")
plt.xlim(0.7, 1.5)
plt.ylim(0.4, 1.8)
plt.title("Collapsed to 1d ($P_\mu$)")
filename = "plots/1d"
plt.savefig(filename + ".png", facecolor="white", dpi=300)
plt.savefig(filename + ".jpg", facecolor="white", dpi=300)
plt.savefig(filename + ".svg", facecolor="white")

plt.figure(figsize=(10,7))
plt.plot([0.7, 1.5], [0.7, 1.5], c="k", ls="dashed", lw=2, zorder=5)

plt.scatter(nuwro_cov_mat_true_MAs_1d, nuwro_cov_mat_reco_MAs_prior_removed_1d, s=s, c="tab:blue", label="600 fake data sets\nfrom covariance matrix variations", zorder=0)
plt.errorbar(nuwro_cov_mat_true_MAs_1d, nuwro_cov_mat_reco_MAs_prior_removed_1d, yerr=nuwro_cov_mat_reco_MA_sigmas_prior_removed_1d, c="tab:blue", fmt="none", capsize=4, lw=1, capthick=1, zorder=0)

plt.scatter(nuwro_xs_cov_mat_true_MAs_1d, nuwro_xs_cov_mat_reco_MAs_prior_removed_1d, s=s, c="tab:orange", label="600 fake data sets\nfrom CV with XS covariance matrix variations", zorder=1)
plt.errorbar(nuwro_xs_cov_mat_true_MAs_1d, nuwro_xs_cov_mat_reco_MAs_prior_removed_1d, yerr=nuwro_xs_cov_mat_reco_MA_sigmas_prior_removed_1d, c="tab:orange", fmt="none", capsize=4, lw=1, capthick=1, zorder=1)

plt.scatter(nuwro_genie_true_MAs_1d, nuwro_genie_reco_MAs_prior_removed_1d, s=s, c="tab:green", label="600 fake data sets\nfrom CV with GENIE universe variations", zorder=1)
plt.errorbar(nuwro_genie_true_MAs_1d, nuwro_genie_reco_MAs_prior_removed_1d, yerr=nuwro_genie_reco_MA_sigmas_prior_removed_1d, c="tab:green", fmt="none", capsize=4, lw=1, capthick=1, zorder=1)

plt.scatter(asimov_true_MA, asimov_reco_MA_prior_removed_1d, s=30, label=f"Asimov fake data: {asimov_reco_MA_prior_removed_1d:.3f} "r"$\pm$"f" {asimov_reco_MA_sigma_prior_removed_1d:.3f} "
            r"$\mathrm{GeV/c^2}$"f"\n\t\t\tTrue: {asimov_true_MA_1d:.3f} "r"$\mathrm{GeV/c^2}$""\n\t\t\t"
            fr"$\sigma = {np.abs(asimov_true_MA_1d - asimov_reco_MA_prior_removed_1d)/asimov_reco_MA_sigma_prior_removed_1d:.3f}$", c="tab:red", zorder=10)
plt.scatter(asimov_true_MA, asimov_reco_MA_prior_removed_1d, s=70, c="k", zorder=9)
plt.errorbar(asimov_true_MA, asimov_reco_MA_prior_removed_1d, yerr=asimov_reco_MA_sigma_prior_removed_1d, fmt="none", c="tab:red", capthick=2, elinewidth=2, capsize=5, zorder=10)
plt.errorbar(asimov_true_MA, asimov_reco_MA_prior_removed_1d, yerr=asimov_reco_MA_sigma_prior_removed_1d, fmt="none", c="k", capthick=4, elinewidth=4, capsize=6, zorder=9)

plt.scatter(nuwro_fake_data_true_MA, nuwro_reco_MA_prior_removed_1d, s=30, label=f"NuWro fake data: {nuwro_reco_MA_prior_removed_1d:.3f} "r"$\pm$"f" {nuwro_reco_MA_sigma_prior_removed_1d:.3f} "
            r"$\mathrm{GeV/c^2}$"f"\n\t\t\tTrue: {nuwro_fake_data_true_MA:.3f} "r"$\mathrm{GeV/c^2}$""\n\t\t\t"
            fr"$\sigma = {np.abs(nuwro_fake_data_true_MA - nuwro_reco_MA_prior_removed_1d)/nuwro_reco_MA_sigma_prior_removed_1d:.3f}$", c="tab:brown", zorder=10)
plt.scatter(nuwro_fake_data_true_MA, nuwro_reco_MA_prior_removed_1d, s=70, c="k", zorder=9)
plt.errorbar(nuwro_fake_data_true_MA, nuwro_reco_MA_prior_removed_1d, yerr=nuwro_reco_MA_sigma_prior_removed_1d, fmt="none", c="tab:brown", capthick=2, elinewidth=2, capsize=5, zorder=10)
plt.errorbar(nuwro_fake_data_true_MA, nuwro_reco_MA_prior_removed_1d, yerr=nuwro_reco_MA_sigma_prior_removed_1d, fmt="none", c="k", capthick=4, elinewidth=4, capsize=6, zorder=9)

plt.scatter(genie_v2_fake_data_true_MA, genie_v2_reco_MA_prior_removed_1d, s=30, label=f"GENIE v2 fake data: {genie_v2_reco_MA_prior_removed_1d:.3f} "r"$\pm$"f" {genie_v2_reco_MA_sigma_prior_removed_1d:.3f} "
            r"$\mathrm{GeV/c^2}$"f"\n\t\t\tTrue: {genie_v2_fake_data_true_MA:.3f} "r"$\mathrm{GeV/c^2}$""\n\t\t\t"
            fr"$\sigma = {np.abs(genie_v2_fake_data_true_MA - genie_v2_reco_MA_prior_removed_1d)/genie_v2_reco_MA_sigma_prior_removed_1d:.3f}$", c="tab:purple", zorder=10)
plt.scatter(genie_v2_fake_data_true_MA, genie_v2_reco_MA_prior_removed_1d, s=70, c="k", zorder=9)
plt.errorbar(genie_v2_fake_data_true_MA, genie_v2_reco_MA_prior_removed_1d, yerr=genie_v2_reco_MA_sigma_prior_removed_1d, fmt="none", c="tab:purple", capthick=2, elinewidth=2, capsize=5, zorder=10)
plt.errorbar(genie_v2_fake_data_true_MA, genie_v2_reco_MA_prior_removed_1d, yerr=genie_v2_reco_MA_sigma_prior_removed_1d, fmt="none", c="k", capthick=4, elinewidth=4, capsize=6, zorder=9)

plt.legend(loc="upper left")
plt.xlabel(r"True $M_A$ (GeV/c$^2$)")
plt.ylabel(r"Reco $M_A$ (GeV/c$^2$)")
plt.xlim(0.7, 1.5)
plt.ylim(0.4, 1.8)
plt.title("Collapsed to 1d ($P_\mu$)")
filename = "plots/1d_no_prior"
plt.savefig(filename + ".png", facecolor="white", dpi=300)
plt.savefig(filename + ".jpg", facecolor="white", dpi=300)
plt.savefig(filename + ".svg", facecolor="white")
